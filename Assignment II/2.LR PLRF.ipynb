# %%
import gurobipy as gp
from gurobipy import GRB, quicksum
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
class Production_data:
    def __init__(self, number_of_periods, number_of_items, demand_forecast, production_cost, holding_cost, setup_cost, item_requirements , capacity):
        self.T=number_of_periods
        self.items=number_of_items
        self.demand_forecast=np.array(demand_forecast)
        self.production_cost=np.array(production_cost)
        self.holding_cost=np.array(holding_cost)
        self.setup_cost=np.array(setup_cost)
        self.item_requirements=np.array(item_requirements)
        self.capacity=np.array(capacity)

file_name = "CLSP+ST-instances Data-R.xlsx"
#file_name = "prova2.xlsx"

xls = pd.ExcelFile(file_name)  # Read the whole file

tables_keywords = ["Demand Forecast:", "Production Cost", "Holding Cost", "Setup Cost", "UnitsOfCapacity", "Capacity"]

# %%
def read_data(xls, sheet_name):
    tables_dict = {}
    df = pd.read_excel(xls, sheet_name=sheet_name)
    
    # Define which column to check for each keyword
    columns_to_check = {
        "Demand Forecast:": 0,
        "Production Cost": 0,
        "Holding Cost": 0,
        "Setup Cost": 0,
        "UnitsOfCapacity": 1,  # Check the second column for this keyword (it also contains setup time(i,2))
        "Capacity": 0
    }
    
    # Iterate through the keywords to find each table
    for keyword in tables_keywords:
        column_idx = columns_to_check.get(keyword, 0)
        
        # Check in the specified column for the keyword
        match = df[df.iloc[:, column_idx].astype(str).str.contains(keyword, na=False)]
        
        if not match.empty:
            table_start_row = match.index[0] + 1
            
            # Find the end of the current table (next keyword or empty rows)
            end_row = None
            for next_keyword in tables_keywords:
                if next_keyword != keyword:
                    next_column_idx = columns_to_check.get(next_keyword, 0)
                    next_match = df.loc[table_start_row:][df.loc[table_start_row:].iloc[:, next_column_idx].astype(str).str.contains(next_keyword, na=False)]
                    if not next_match.empty:
                        potential_end = next_match.index[0]
                        if end_row is None or potential_end < end_row:
                            end_row = potential_end
            
            # If no next keyword found, look for empty rows
            if end_row is None:
                for i in range(table_start_row, len(df)):
                    # Check if row is empty or contains only NaN values
                    if df.iloc[i].isna().all():
                        end_row = i
                        break
            
            # If still no end found, use the end of the dataframe
            if end_row is None:
                end_row = len(df)
            
            # Extract the table
            table_df = df.iloc[table_start_row:end_row]
            
            # Remove completely empty rows
            table_df = table_df.dropna(how='all')
            
            # Remove completely empty columns
            table_df = table_df.dropna(axis=1, how='all')
            
            # Remove any remaining NaN values by filling with 0
            table_df = table_df.fillna(0)
            
            # Convert to numpy array
            table = table_df.to_numpy()
            tables_dict[keyword] = table
    
    # Create an instance of Production_data class
    production_data = Production_data(
        tables_dict.get("Demand Forecast:", np.zeros((1,1))).shape[1]-1,
        tables_dict.get("Demand Forecast:", np.zeros((1,1))).shape[0]-1,  
        tables_dict.get("Demand Forecast:", np.zeros((1,1))),  
        tables_dict.get("Production Cost", np.zeros((1,1))),  
        tables_dict.get("Holding Cost", np.zeros((1,1))),  
        tables_dict.get("Setup Cost", np.zeros((1,1))),  
        tables_dict.get("UnitsOfCapacity", np.zeros((1,1))),  
        tables_dict.get("Capacity", np.zeros((1,1)))

    )
    
    production_data.capacity = np.vstack([
    np.zeros((1, production_data.capacity.shape[1]), dtype=production_data.capacity.dtype),production_data.capacity])

    production_data.item_requirements = np.vstack([
    np.zeros((1, production_data.item_requirements.shape[1]), dtype=production_data.item_requirements.dtype),production_data.item_requirements
])
    return production_data

# %%
def solve_PLRF(data, sheet_name, results_df):

    model=gp.Model("PLRF")


    #decisions variables

    T=data.T
    O=data.items

    w=model.addVars(O+1, T+1, T+1, vtype=GRB.CONTINUOUS, lb=0, ub=1, name = "w" )#fraction of demand of item i produced in period s to satisfy period t
    y=model.addVars(O+1, T+1, vtype=GRB.BINARY, name="y") #produce or not for item i in period i

    model.setObjective(
        #setup cost
        quicksum(quicksum( data.setup_cost[i, t] * y[i, t] for i in range(1, O+1) ) for t in range(1, T+1))+
        #production cost, j is actual period and t in future period
        quicksum(quicksum(quicksum(data.production_cost[i, s] * data.demand_forecast[i,t] * w[i, s, t] 
                          for t in range(s, T+1)) # Changed range
                 for s in range(1, T+1))
        for i in range(1, O+1))+
        #holding cost, i per item
        quicksum( quicksum(quicksum
                           (sum(data.holding_cost[ i, t] for t in range(s, j)) * data.demand_forecast[i, j] * w[i, s, j] for j in range(s+1, T+1))
                           for s in range(1, T+1)) for i in range(1, O+1)),
        GRB.MINIMIZE
    )
    
    

    
    # Each demand must be fully satisfied (like each customer must be served) for each item
    for i in range(1, O+1):
        for t in range(1, T+1):
            model.addConstr( quicksum(w[i, s, t] for s in range(1, t+1)) == 1, name= f"demand_{i}{t}")
            
    #cannot produce any fraction of demand in period s is the variable y is 0, for item i
    for i in range(1, O+1):
        for t in range(1, T+1):
            for s in range(1, t+1):
                model.addConstr( w[i, s, t] <= y[i, s] )
        
    #still capacity constraints fossure
    #constraint 3

    for s in range(1, T+1):
        model.addConstr(
            quicksum(
                # Production time: sum over all demands being produced in period s
                sum(w[i, s, t] * data.demand_forecast[i, t] for t in range(s, T+1)) * data.item_requirements[i, 1] +
                # Setup time
                data.item_requirements[i, 2] * y[i, s]
                for i in range(1, O+1)
            ) <= data.capacity[s, 1],
            name=f"capacity_{s}"
        )
        
    
    #constraint 4
    for t in range(1, T+1):
        for i in range(1, O+1):
            model.addConstr( sum( w[i, t, s] for s in range(t, T+1) )-(quicksum(data.demand_forecast[i, q] for q in range(t, T+1))) * y[i, t]<=0)

    
    #solve
    model.setParam('TimeLimit', 20*60)
    model.optimize()

    if model.status == GRB.OPTIMAL:

        print("\noptimal solution found:")

        # Create a list to store all periods' results for this sheet
        period_results = []
        
        # Collect results for each period
        for t in range(1, T+1):
            period_results.append({
                "Sheet": sheet_name,
                "Period": t,
                "Setup Decision": y[1, t].X,
                "Production Quantity": sum(w[2, t, j].X * data.demand_forecast[2, j] for j in range(t, T+1)),
                "Capacity Usage": sum(sum(w[i, t, j].X * data.demand_forecast[i, j] * data.item_requirements[i, 1] + data.item_requirements[i, 2] * y[i,t].X  
                                        for j in range(t, T+1)) 
                                    for i in range(1, O+1)) / data.capacity[t, 1],
                "Total Cost": model.objVal
            })
        
        sheet_results = pd.DataFrame(period_results)
        results_df = pd.concat([ results_df, sheet_results ], ignore_index=False)


    return results_df, model.ObjVal

# %%
results_df = pd.DataFrame(columns=["Sheet", "Period", "Inventory of item 1", "Produced for item 1"])
sheet_list=["Data-20-12 (1)", "Data-20-12 (2)", "Data-20-24 (1)", "Data-20-24 (2)" , "Data-100-24 (1)", "Data-100-24 (2)",
            "Data-200-24" ]

ObjVals = []

for sheet_name in sheet_list:
    break
    print(sheet_name)
    data = read_data(xls, sheet_name=sheet_name)
    
    start = time.time()
    results_df, Z = solve_PLRF(data, sheet_name, results_df)
    end = time.time()
    ObjVals.append((Z, end-start))

# %%
print(results_df)
# Out:
# Empty DataFrame
# Columns: [Sheet, Period, Inventory of item 1, Produced for item 1]
# Index: []

# %%
print(ObjVals)
# Out:
# []

# %%
def Lagrangian_Relaxation_PLRF(data, optimal_value):
    model = gp.Model("PLRF_LR")

    T = data.T
    O = data.items

    # Initialize Lagrange multipliers
    mu = np.ones(T + 1)  # +1 because periods start from 1
    dual_bounds = []
    best_dual_bound = float('-inf')
    
    iteration = 0
    max_iterations = 1000
    tolerance = 0.05
    
    start = time.time()
    end = time.time()
    while iteration <= max_iterations and end-start <= 10*60:
        iteration += 1
        print(f'Iteration: {iteration}')
        
        # Decision variables
        w = model.addVars(O+1, T+1, T+1, vtype=GRB.CONTINUOUS, lb=0, ub=1, name="w")
        y = model.addVars(O+1, T+1, vtype=GRB.BINARY, name="y")
        
        # Objective function with relaxed capacity constraints
        model.setObjective(
            # Setup cost
            quicksum(quicksum(data.setup_cost[i, t] * y[i, t] for i in range(1, O+1)) for t in range(1, T+1)) +
            # Production cost
            quicksum(quicksum(quicksum(data.production_cost[i, s] * data.demand_forecast[i,t] * w[i, s, t] 
                              for t in range(s, T+1))
                     for s in range(1, T+1))
            for i in range(1, O+1)) +
            # Holding cost
            quicksum(quicksum(quicksum(
                       sum(data.holding_cost[i, t] for t in range(s, j)) * data.demand_forecast[i, j] * w[i, s, j] 
                       for j in range(s+1, T+1))
                   for s in range(1, T+1)) for i in range(1, O+1)) +
            # Lagrangian term for relaxed capacity constraints
            quicksum(mu[s] * (
                quicksum(
                    sum(w[i, s, t] * data.demand_forecast[i, t] for t in range(s, T+1)) * data.item_requirements[i, 1] +
                    data.item_requirements[i, 2] * y[i, s]
                    for i in range(1, O+1)
                ) - data.capacity[s, 1]
            ) for s in range(1, T+1)),
            GRB.MINIMIZE
        )
        
        # Original constraints (excluding the relaxed capacity constraints)
        # Each demand must be fully satisfied
        for i in range(1, O+1):
            for t in range(1, T+1):
                model.addConstr(quicksum(w[i, s, t] for s in range(1, t+1)) == 1, name=f"demand_{i}{t}")
        
        # Production fraction constraint
        for i in range(1, O+1):
            for t in range(1, T+1):
                for s in range(1, t+1):
                    model.addConstr(w[i, s, t] <= y[i, s])
        
        # Additional constraint from original formulation
        for t in range(1, T+1):
            for i in range(1, O+1):
                model.addConstr(sum(w[i, t, s] for s in range(t, T+1)) - 
                               (quicksum(data.demand_forecast[i, q] for q in range(t, T+1))) * y[i, t] <= 0)
        
        model.optimize()
        end = time.time()

        if model.status == GRB.OPTIMAL:
            dual_obj = model.ObjVal
            dual_bounds.append(dual_obj)
            best_dual_bound = max(best_dual_bound, dual_obj)
            
            # Calculate subgradients for capacity constraints
            subgradient = np.zeros(T + 1)
            for s in range(1, T+1):
                subgradient[s] = sum(
                    sum(w[i, s, t].X * data.demand_forecast[i, t] for t in range(s, T+1)) * data.item_requirements[i, 1] +
                    data.item_requirements[i, 2] * y[i, s].X
                    for i in range(1, O+1)
                ) - data.capacity[s, 1]
            
            # Update Lagrange multipliers
            step_size = 1.0 / iteration  # Decreasing step size
            # mu = np.maximum(0, mu + step_size * subgradient)
            mu = np.maximum(0, mu + subgradient/np.max(np.abs(subgradient)*10))
            
            # Check for convergence
            if iteration > 25:
                recent_avg = np.mean(dual_bounds[-25:])
                if np.abs(recent_avg - best_dual_bound) / (best_dual_bound + 1e-6) < tolerance:
                    break
        else:
            print("Model not optimal in iteration", iteration)
            break
    
    gap = (optimal_value - best_dual_bound) / optimal_value if optimal_value != 0 else 0

    plt.figure(figsize=(10, 6))
    plt.plot(dual_bounds)
    plt.axhline(best_dual_bound, linestyle='--', color='red', linewidth=0.5, 
                label=f'Best Dual Bound: {best_dual_bound:.2f}')
    plt.axhline(optimal_value, linestyle='--', color='b', linewidth=0.5, 
                label=f'Optimal value: {optimal_value:.2f}')
    plt.title(f'Dual Bounds, Gap: {round(gap, 4)*100} %')
    plt.legend()
    plt.show()

    return best_dual_bound

# %%
results_LR = []
sheet_list=["Data-20-12 (1)", "Data-20-12 (2)", "Data-20-24 (1)", "Data-20-24 (2)" , "Data-100-24 (1)", "Data-100-24 (2)",
            "Data-200-24" ]

optimal_values = {'Data-20-12 (1)': 89469.0,
                  'Data-20-12 (2)': 14330786.370279722,
                  'Data-20-24 (1)': 5227122.577272725,
                  'Data-20-24 (2)': 6711666.365537237,
                  'Data-100-24 (1)': 37944696.08376624,
                  'Data-100-24 (2)': 37944696.08376624,
                  'Data-200-24': 75798079.88268259}

# %%
sheet_name = sheet_list[0]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-20-12 (1)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-04
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2040 rows, 3822 columns and 6480 nonzeros
# Model fingerprint: 0xff2dcad0
# Variable types: 3549 continuous, 273 integer (273 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 84677.000000
# Presolve removed 1965 rows and 3744 columns
# Presolve time: 0.01s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Found heuristic solution: objective 47835.000000
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 4.754600e+04, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    47546.000000 47546.0000  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 47546 47835 84677
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.754600000000e+04, best bound 4.754600000000e+04, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4080 rows, 7644 columns and 12960 nonzeros
# Model fingerprint: 0xa5e97970
# Variable types: 7098 continuous, 546 integer (546 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 49159.5 (0.03s)
# Loaded MIP start from previous solve with objective 49159.5
#
# Presolve removed 4005 rows and 7566 columns
# Presolve time: 0.02s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 63 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      49159.4575 49159.4575  0.00%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 49159.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.915945754443e+04, best bound 4.915945754443e+04, gap 0.0000%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 6120 rows, 11466 columns and 19440 nonzeros
# Model fingerprint: 0x629230cb
# Variable types: 10647 continuous, 819 integer (819 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 49907.3 (0.02s)
# Loaded MIP start from previous solve with objective 49907.3
#
# Presolve removed 6045 rows and 11388 columns
# Presolve time: 0.02s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 61 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      49907.3120 49905.8269  0.00%     -    0s
#
# Explored 1 nodes (61 simplex iterations) in 0.06 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 49907.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.990731204615e+04, best bound 4.990582685638e+04, gap 0.0030%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8160 rows, 15288 columns and 25920 nonzeros
# Model fingerprint: 0xb0cbd545
# Variable types: 14196 continuous, 1092 integer (1092 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 50557.2 (0.03s)
# Loaded MIP start from previous solve with objective 50557.2
#
# Presolve removed 8085 rows and 15210 columns
# Presolve time: 0.02s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 58 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      50557.2328 50557.2328  0.00%     -    0s
#
# Explored 1 nodes (58 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 50557.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.055723277853e+04, best bound 5.055723277853e+04, gap 0.0000%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 10200 rows, 19110 columns and 32400 nonzeros
# Model fingerprint: 0x8e4d5c30
# Variable types: 17745 continuous, 1365 integer (1365 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 52189 (0.03s)
# Loaded MIP start from previous solve with objective 52189
#
# Presolve removed 10125 rows and 19032 columns
# Presolve time: 0.03s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      52188.9774 52183.9571  0.01%     -    0s
#
# Explored 1 nodes (59 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 52189
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.218897736579e+04, best bound 5.218395705347e+04, gap 0.0096%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12240 rows, 22932 columns and 38880 nonzeros
# Model fingerprint: 0x0b04f084
# Variable types: 21294 continuous, 1638 integer (1638 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 52290.8 (0.04s)
# Loaded MIP start from previous solve with objective 52290.8
#
# Presolve removed 12165 rows and 22854 columns
# Presolve time: 0.03s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      52290.8001 52288.1417  0.01%     -    0s
#
# Explored 1 nodes (48 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 52290.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.229080006291e+04, best bound 5.228814168369e+04, gap 0.0051%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 14280 rows, 26754 columns and 45360 nonzeros
# Model fingerprint: 0x32ea2f37
# Variable types: 24843 continuous, 1911 integer (1911 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 55715.9 (0.04s)
# Loaded MIP start from previous solve with objective 55715.9
#
# Presolve removed 14205 rows and 26676 columns
# Presolve time: 0.03s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      55715.8859 55715.8859  0.00%     -    0s
#
# Explored 1 nodes (51 simplex iterations) in 0.08 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 55715.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.571588587555e+04, best bound 5.571588587555e+04, gap 0.0000%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 16320 rows, 30576 columns and 51840 nonzeros
# Model fingerprint: 0x3e51fa0a
# Variable types: 28392 continuous, 2184 integer (2184 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 57662.3 (0.04s)
# Loaded MIP start from previous solve with objective 57662.3
#
# Presolve removed 16245 rows and 30498 columns
# Presolve time: 0.03s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      57662.2840 57662.2840  0.00%     -    0s
#
# Explored 1 nodes (49 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 57662.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.766228402433e+04, best bound 5.766228402433e+04, gap 0.0000%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 18360 rows, 34398 columns and 58320 nonzeros
# Model fingerprint: 0xa58fac9b
# Variable types: 31941 continuous, 2457 integer (2457 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 58824.3 (0.04s)
# Loaded MIP start from previous solve with objective 58824.3
#
# Presolve removed 18285 rows and 34320 columns
# Presolve time: 0.04s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      58824.2705 58820.6849  0.01%     -    0s
#
# Explored 1 nodes (48 simplex iterations) in 0.09 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 58824.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.882427054680e+04, best bound 5.882068493975e+04, gap 0.0061%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 20400 rows, 38220 columns and 64800 nonzeros
# Model fingerprint: 0x7ea4117c
# Variable types: 35490 continuous, 2730 integer (2730 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 60016.6 (0.04s)
# Loaded MIP start from previous solve with objective 60016.6
#
# Presolve removed 20325 rows and 38142 columns
# Presolve time: 0.04s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      60016.5850 60016.5850  0.00%     -    0s
#
# Explored 1 nodes (46 simplex iterations) in 0.09 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 60016.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.001658504117e+04, best bound 6.001658504117e+04, gap 0.0000%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 22440 rows, 42042 columns and 71280 nonzeros
# Model fingerprint: 0x30a18ec4
# Variable types: 39039 continuous, 3003 integer (3003 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 61471.2 (0.04s)
# Loaded MIP start from previous solve with objective 61471.2
#
# Presolve removed 22365 rows and 41964 columns
# Presolve time: 0.04s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      61471.2302 61465.9184  0.01%     -    0s
#
# Explored 1 nodes (45 simplex iterations) in 0.09 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 61471.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.147123020370e+04, best bound 6.146591840243e+04, gap 0.0086%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 24480 rows, 45864 columns and 77760 nonzeros
# Model fingerprint: 0xc22fdb21
# Variable types: 42588 continuous, 3276 integer (3276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 63079 (0.05s)
# Loaded MIP start from previous solve with objective 63079
#
# Presolve removed 24405 rows and 45786 columns
# Presolve time: 0.05s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      63078.9697 63074.1506  0.01%     -    0s
#
# Explored 1 nodes (44 simplex iterations) in 0.11 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 63079
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.307896974947e+04, best bound 6.307415064935e+04, gap 0.0076%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 26520 rows, 49686 columns and 84240 nonzeros
# Model fingerprint: 0x9bee2773
# Variable types: 46137 continuous, 3549 integer (3549 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 64555.6 (0.04s)
# Loaded MIP start from previous solve with objective 64555.6
#
# Presolve removed 26445 rows and 49608 columns
# Presolve time: 0.05s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: cutoff, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      64555.5718 64555.5718  0.00%     -    0s
#
# Explored 1 nodes (45 simplex iterations) in 0.11 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 64555.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.455557178372e+04, best bound 6.455557178372e+04, gap 0.0000%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 28560 rows, 53508 columns and 90720 nonzeros
# Model fingerprint: 0xce79d925
# Variable types: 49686 continuous, 3822 integer (3822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 64917.2 (0.05s)
# Loaded MIP start from previous solve with objective 64917.2
#
# Presolve removed 28485 rows and 53430 columns
# Presolve time: 0.05s
# Presolved: 75 rows, 78 columns, 197 nonzeros
# Variable types: 23 continuous, 55 integer (55 binary)
#
# Root relaxation: interrupted, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      64917.2024 64910.8079  0.01%     -    0s
#
# Explored 1 nodes (42 simplex iterations) in 0.12 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 64917.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.491720239647e+04, best bound 6.491080787196e+04, gap 0.0099%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 30600 rows, 57330 columns and 97200 nonzeros
# Model fingerprint: 0x0cb54889
# Variable types: 53235 continuous, 4095 integer (4095 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 66184.9 (0.05s)
# Loaded MIP start from previous solve with objective 66184.9
#
# Presolve removed 29188 rows and 55866 columns
# Presolve time: 0.02s
# Presolved: 1412 rows, 1464 columns, 3684 nonzeros
# Variable types: 364 continuous, 1100 integer (1100 binary)
#
# Root relaxation: cutoff, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      66184.8917 66184.8917  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.10 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 66184.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.618489166634e+04, best bound 6.618489166634e+04, gap 0.0000%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 32640 rows, 61152 columns and 103680 nonzeros
# Model fingerprint: 0xd7559226
# Variable types: 56784 continuous, 4368 integer (4368 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 67939.9 (0.03s)
# Loaded MIP start from previous solve with objective 67939.9
#
# Presolve removed 30900 rows and 59572 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      67939.9167 67933.7892  0.01%     -    0s
#
# Explored 1 nodes (41 simplex iterations) in 0.08 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 67939.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.793991673297e+04, best bound 6.793378921798e+04, gap 0.0090%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34680 rows, 64974 columns and 110160 nonzeros
# Model fingerprint: 0xc85ff94d
# Variable types: 60333 continuous, 4641 integer (4641 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 68679.3 (0.04s)
# Loaded MIP start from previous solve with objective 68679.3
#
# Presolve removed 32940 rows and 63394 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      68679.3051 68679.3051  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 68679.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.867930512698e+04, best bound 6.867930512698e+04, gap 0.0000%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 36720 rows, 68796 columns and 116640 nonzeros
# Model fingerprint: 0x171f4a4c
# Variable types: 63882 continuous, 4914 integer (4914 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 70494.6 (0.04s)
# Loaded MIP start from previous solve with objective 70494.6
#
# Presolve removed 34980 rows and 67216 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      70494.5809 70494.5809  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 70494.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.049458093405e+04, best bound 7.049458093405e+04, gap 0.0000%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 38760 rows, 72618 columns and 123120 nonzeros
# Model fingerprint: 0xa480026e
# Variable types: 67431 continuous, 5187 integer (5187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 71958.3 (0.04s)
# Loaded MIP start from previous solve with objective 71958.3
#
# Presolve removed 37020 rows and 71038 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 43 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      71958.3304 71958.3304  0.00%     -    0s
#
# Explored 1 nodes (43 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 71958.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.195833038880e+04, best bound 7.195833038880e+04, gap 0.0000%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 40800 rows, 76440 columns and 129600 nonzeros
# Model fingerprint: 0xabe8bc69
# Variable types: 70980 continuous, 5460 integer (5460 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 73635.7 (0.03s)
# Loaded MIP start from previous solve with objective 73635.7
#
# Presolve removed 39060 rows and 74860 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      73635.7035 73633.3957  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 73635.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.363570350623e+04, best bound 7.363339573412e+04, gap 0.0031%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 42840 rows, 80262 columns and 136080 nonzeros
# Model fingerprint: 0x73d7b021
# Variable types: 74529 continuous, 5733 integer (5733 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 74324.1 (0.04s)
# Loaded MIP start from previous solve with objective 74324.1
#
# Presolve removed 41100 rows and 78682 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      74324.1070 74319.4637  0.01%     -    0s
#
# Explored 1 nodes (41 simplex iterations) in 0.09 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 74324.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.432410696177e+04, best bound 7.431946374947e+04, gap 0.0062%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 44880 rows, 84084 columns and 142560 nonzeros
# Model fingerprint: 0x32a63702
# Variable types: 78078 continuous, 6006 integer (6006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 75278.6 (0.05s)
# Loaded MIP start from previous solve with objective 75278.6
#
# Presolve removed 43140 rows and 82504 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      75278.5683 75272.6862  0.01%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 75278.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.527856831636e+04, best bound 7.527268620930e+04, gap 0.0078%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 46920 rows, 87906 columns and 149040 nonzeros
# Model fingerprint: 0x8daeb64b
# Variable types: 81627 continuous, 6279 integer (6279 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [7e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 76165.8 (0.05s)
# Loaded MIP start from previous solve with objective 76165.8
#
# Presolve removed 45180 rows and 86326 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      76165.7796 76159.0617  0.01%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 76165.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.616577958096e+04, best bound 7.615906171786e+04, gap 0.0088%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 48960 rows, 91728 columns and 155520 nonzeros
# Model fingerprint: 0x5ce1e43d
# Variable types: 85176 continuous, 6552 integer (6552 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [6e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 76483.2 (0.04s)
# Loaded MIP start from previous solve with objective 76483.2
#
# Presolve removed 47220 rows and 90148 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      76483.1947 76476.1707  0.01%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 76483.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.648319469375e+04, best bound 7.647617066038e+04, gap 0.0092%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 51000 rows, 95550 columns and 162000 nonzeros
# Model fingerprint: 0xff1bb00e
# Variable types: 88725 continuous, 6825 integer (6825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [3e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 77761.6 (0.05s)
# Loaded MIP start from previous solve with objective 77761.6
#
# Presolve removed 49260 rows and 93970 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 39 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      77761.6466 77761.6466  0.00%     -    0s
#
# Explored 1 nodes (39 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 77761.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.776164659854e+04, best bound 7.776164659854e+04, gap 0.0000%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 53040 rows, 99372 columns and 168480 nonzeros
# Model fingerprint: 0x72b88d4a
# Variable types: 92274 continuous, 7098 integer (7098 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 78533.5 (0.05s)
# Loaded MIP start from previous solve with objective 78533.5
#
# Presolve removed 51300 rows and 97792 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      78533.4925 78533.4925  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.11 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 78533.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.853349246135e+04, best bound 7.853349246135e+04, gap 0.0000%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 55080 rows, 103194 columns and 174960 nonzeros
# Model fingerprint: 0xdb89326d
# Variable types: 95823 continuous, 7371 integer (7371 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [4e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 79156.4 (0.05s)
# Loaded MIP start from previous solve with objective 79156.4
#
# Presolve removed 53340 rows and 101614 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 35 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      79156.3629 79151.3880  0.01%     -    0s
#
# Explored 1 nodes (35 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 79156.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.915636289929e+04, best bound 7.915138804220e+04, gap 0.0063%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 57120 rows, 107016 columns and 181440 nonzeros
# Model fingerprint: 0x2ae695b0
# Variable types: 99372 continuous, 7644 integer (7644 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [6e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 80033.8 (0.05s)
# Loaded MIP start from previous solve with objective 80033.8
#
# Presolve removed 55380 rows and 105436 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#      0     0          -    0      80033.8457 80028.5179  0.01%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 80033.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.003384574509e+04, best bound 8.002851793777e+04, gap 0.0067%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 59160 rows, 110838 columns and 187920 nonzeros
# Model fingerprint: 0xd2f64bc2
# Variable types: 102921 continuous, 7917 integer (7917 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [3e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 80808.1 (0.05s)
# Loaded MIP start from previous solve with objective 80808.1
#
# Presolve removed 57420 rows and 109258 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 37 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      80808.1436 80804.3881  0.00%     -    0s
#
# Explored 1 nodes (37 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 80808.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.080814356178e+04, best bound 8.080438810627e+04, gap 0.0046%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 61200 rows, 114660 columns and 194400 nonzeros
# Model fingerprint: 0x51aaa6f1
# Variable types: 106470 continuous, 8190 integer (8190 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [7e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 80933.2 (0.05s)
# Loaded MIP start from previous solve with objective 80933.2
#
# Presolve removed 59460 rows and 113080 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 37 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      80933.2017 80928.8047  0.01%     -    0s
#
# Explored 1 nodes (37 simplex iterations) in 0.10 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 80933.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.093320170082e+04, best bound 8.092880471252e+04, gap 0.0054%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 63240 rows, 118482 columns and 200880 nonzeros
# Model fingerprint: 0xc57f018b
# Variable types: 110019 continuous, 8463 integer (8463 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 81241.9 (0.05s)
# Loaded MIP start from previous solve with objective 81241.9
#
# Presolve removed 61500 rows and 116902 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 37 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      81241.9073 81241.9073  0.00%     -    0s
#
# Explored 1 nodes (37 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 81241.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.124190725561e+04, best bound 8.124190725561e+04, gap 0.0000%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 65280 rows, 122304 columns and 207360 nonzeros
# Model fingerprint: 0x3010ebd3
# Variable types: 113568 continuous, 8736 integer (8736 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [8e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 81848.6 (0.06s)
# Loaded MIP start from previous solve with objective 81848.6
#
# Presolve removed 63540 rows and 120724 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      81848.6275 81848.6275  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.11 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 81848.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.184862745527e+04, best bound 8.184862745527e+04, gap 0.0000%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 67320 rows, 126126 columns and 213840 nonzeros
# Model fingerprint: 0x665d6453
# Variable types: 117117 continuous, 9009 integer (9009 binary)
# Coefficient statistics:
# ...
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 83338.5 (0.05s)
# Loaded MIP start from previous solve with objective 83338.5
#
# Presolve removed 71700 rows and 136012 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      83338.5160 83338.5160  0.00%     -    0s
#
# Explored 1 nodes (41 simplex iterations) in 0.12 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 83338.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.333851595481e+04, best bound 8.333851595481e+04, gap 0.0000%
# Iteration: 37
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 75480 rows, 141414 columns and 239760 nonzeros
# Model fingerprint: 0x269dbffe
# Variable types: 131313 continuous, 10101 integer (10101 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 83288.6 (0.06s)
# Loaded MIP start from previous solve with objective 83288.6
#
# Presolve removed 73740 rows and 139834 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      83288.6351 83285.4163  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.13 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 83288.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.328863514492e+04, best bound 8.328541630203e+04, gap 0.0039%
# Iteration: 38
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 77520 rows, 145236 columns and 246240 nonzeros
# Model fingerprint: 0x5550df79
# Variable types: 134862 continuous, 10374 integer (10374 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [2e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 83288.9 (0.06s)
# Loaded MIP start from previous solve with objective 83288.9
#
# Presolve removed 75780 rows and 143656 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      83288.8652 83281.9177  0.01%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.14 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 83288.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.328886515510e+04, best bound 8.328191774600e+04, gap 0.0083%
# Iteration: 39
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 79560 rows, 149058 columns and 252720 nonzeros
# Model fingerprint: 0x0b0278be
# Variable types: 138411 continuous, 10647 integer (10647 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [4e-01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 84668.7 (0.05s)
# Loaded MIP start from previous solve with objective 84668.7
#
# Presolve removed 77820 rows and 147478 columns
# Presolve time: 0.02s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      84668.7447 84668.7447  0.00%     -    0s
# Explored 1 nodes (42 simplex iterations) in 0.13 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 84668.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.466874474033e+04, best bound 8.466874474033e+04, gap 0.0000%
# Iteration: 40
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 81600 rows, 152880 columns and 259200 nonzeros
# Model fingerprint: 0x3dd7630f
# Variable types: 141960 continuous, 10920 integer (10920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [8e-01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 83779 (0.07s)
# Loaded MIP start from previous solve with objective 83779
#
# Presolve removed 79860 rows and 151300 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      83779.0166 83779.0166  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.15 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 83779
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.377901659148e+04, best bound 8.377901659148e+04, gap 0.0000%
# Iteration: 41
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 83640 rows, 156702 columns and 265680 nonzeros
# Model fingerprint: 0xfb797265
# Variable types: 145509 continuous, 11193 integer (11193 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [4e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 84641.6 (0.06s)
# Loaded MIP start from previous solve with objective 84641.6
#
# Presolve removed 81900 rows and 155122 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      84641.5630 84638.4278  0.00%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.15 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 84641.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.464156304723e+04, best bound 8.463842780792e+04, gap 0.0037%
# Iteration: 42
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 85680 rows, 160524 columns and 272160 nonzeros
# Model fingerprint: 0x5f985373
# Variable types: 149058 continuous, 11466 integer (11466 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [8e-01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 85476.9 (0.06s)
# Loaded MIP start from previous solve with objective 85476.9
#
# Presolve removed 83940 rows and 158944 columns
# Presolve time: 0.04s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      85476.9434 85471.6747  0.01%     -    0s
#
# Explored 1 nodes (42 simplex iterations) in 0.16 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 85476.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.547694340435e+04, best bound 8.547167473474e+04, gap 0.0062%
# Iteration: 43
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 87720 rows, 164346 columns and 278640 nonzeros
# Model fingerprint: 0xeaab933c
# Variable types: 152607 continuous, 11739 integer (11739 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [7e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 84126.6 (0.06s)
# Loaded MIP start from previous solve with objective 84126.6
#
# Presolve removed 85980 rows and 162766 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      84126.5970 84118.8362  0.01%     -    0s
#
# Explored 1 nodes (41 simplex iterations) in 0.15 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 84126.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.412659702102e+04, best bound 8.411883623921e+04, gap 0.0092%
# Iteration: 44
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 89760 rows, 168168 columns and 285120 nonzeros
# Model fingerprint: 0x8da03df7
# Variable types: 156156 continuous, 12012 integer (12012 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [5e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 85108.9 (0.07s)
# Loaded MIP start from previous solve with objective 85108.9
#
# Presolve removed 88020 rows and 166588 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      85108.8786 85108.8786  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.16 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 85108.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.510887858832e+04, best bound 8.510887858832e+04, gap 0.0000%
# Iteration: 45
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 91800 rows, 171990 columns and 291600 nonzeros
# Model fingerprint: 0xdd240b60
# Variable types: 159705 continuous, 12285 integer (12285 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 85839.1 (0.07s)
# Loaded MIP start from previous solve with objective 85839.1
#
# Presolve removed 90060 rows and 170410 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      85839.0885 85833.7608  0.01%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.15 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 85839.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.583908850059e+04, best bound 8.583376083663e+04, gap 0.0062%
# Iteration: 46
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 93840 rows, 175812 columns and 298080 nonzeros
# Model fingerprint: 0xd91144ea
# Variable types: 163254 continuous, 12558 integer (12558 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [3e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 85561.6 (0.07s)
# Loaded MIP start from previous solve with objective 85561.6
#
# Presolve removed 92100 rows and 174232 columns
# Presolve time: 0.03s
# Presolved: 1740 rows, 1580 columns, 5520 nonzeros
# Variable types: 1360 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 37 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      85561.5901 85553.9589  0.01%     -    0s
#
# Explored 1 nodes (37 simplex iterations) in 0.16 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 85561.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.556159007270e+04, best bound 8.555395891648e+04, gap 0.0089%

# %%
sheet_name = sheet_list[1]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-20-12 (2)
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2040 rows, 3822 columns and 6480 nonzeros
# Model fingerprint: 0xa6eeef50
# Variable types: 3549 continuous, 273 integer (273 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.933180e+07
# Presolve removed 2040 rows and 3822 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 2: 7.48156e+06 1.93318e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.481564000000e+06, best bound 7.481564000000e+06, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4080 rows, 7644 columns and 12960 nonzeros
# Model fingerprint: 0xe2dd4be6
# Variable types: 7098 continuous, 546 integer (546 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 7.70289e+06 (0.01s)
# Loaded MIP start from previous solve with objective 7.70289e+06
#
# Presolve removed 4080 rows and 7644 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 7.70289e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.702890026259e+06, best bound 7.702890026259e+06, gap 0.0000%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 6120 rows, 11466 columns and 19440 nonzeros
# Model fingerprint: 0x7a2631fd
# Variable types: 10647 continuous, 819 integer (819 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 7.9023e+06 (0.01s)
# Loaded MIP start from previous solve with objective 7.9023e+06
#
# Presolve removed 6120 rows and 11466 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 7.9023e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.902297489433e+06, best bound 7.902297489433e+06, gap 0.0000%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 8160 rows, 15288 columns and 25920 nonzeros
# Model fingerprint: 0x8405b69a
# Variable types: 14196 continuous, 1092 integer (1092 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.09499e+06 (0.01s)
# Loaded MIP start from previous solve with objective 8.09499e+06
#
# Presolve removed 8160 rows and 15288 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 8.09499e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.094988271328e+06, best bound 8.094988271328e+06, gap 0.0000%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 10200 rows, 19110 columns and 32400 nonzeros
# Model fingerprint: 0x4b64acc6
# Variable types: 17745 continuous, 1365 integer (1365 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.27707e+06 (0.02s)
# Loaded MIP start from previous solve with objective 8.27707e+06
#
# Presolve removed 10163 rows and 19073 columns
# Presolve time: 0.01s
# Presolved: 37 rows, 37 columns, 90 nonzeros
# Variable types: 0 continuous, 37 integer (37 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      8277065.91 8276387.84  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 8.27707e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.277065908348e+06, best bound 8.276387838643e+06, gap 0.0082%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12240 rows, 22932 columns and 38880 nonzeros
# Model fingerprint: 0x89ce32e1
# Variable types: 21294 continuous, 1638 integer (1638 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.43677e+06 (0.02s)
# Loaded MIP start from previous solve with objective 8.43677e+06
#
# Presolve removed 12240 rows and 22932 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.04 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 8.43677e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.436770660051e+06, best bound 8.436770660051e+06, gap 0.0000%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 14280 rows, 26754 columns and 45360 nonzeros
# Model fingerprint: 0x9f36ae7a
# Variable types: 24843 continuous, 1911 integer (1911 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.58179e+06 (0.03s)
# Loaded MIP start from previous solve with objective 8.58179e+06
#
# Presolve removed 14280 rows and 26754 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 8.58179e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.581786645789e+06, best bound 8.581786645789e+06, gap 0.0000%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 16320 rows, 30576 columns and 51840 nonzeros
# Model fingerprint: 0xfa5be480
# Variable types: 28392 continuous, 2184 integer (2184 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.73365e+06 (0.02s)
# Loaded MIP start from previous solve with objective 8.73365e+06
#
# Presolve removed 16320 rows and 30576 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.05 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 8.73365e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.733653790533e+06, best bound 8.733653790533e+06, gap 0.0000%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 18360 rows, 34398 columns and 58320 nonzeros
# Model fingerprint: 0xf081341f
# Variable types: 31941 continuous, 2457 integer (2457 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 8.88269e+06 (0.01s)
# Loaded MIP start from previous solve with objective 8.88269e+06
#
# Presolve removed 18360 rows and 34398 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.05 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 8.88269e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.882692540358e+06, best bound 8.882692540358e+06, gap 0.0000%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 20400 rows, 38220 columns and 64800 nonzeros
# Model fingerprint: 0x847b6fd5
# Variable types: 35490 continuous, 2730 integer (2730 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.03107e+06 (0.02s)
# Loaded MIP start from previous solve with objective 9.03107e+06
#
# Presolve removed 20400 rows and 38220 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.06 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 9.03107e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.031073391040e+06, best bound 9.031073391040e+06, gap 0.0000%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 22440 rows, 42042 columns and 71280 nonzeros
# Model fingerprint: 0x96f29923
# Variable types: 39039 continuous, 3003 integer (3003 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.17649e+06 (0.02s)
# Loaded MIP start from previous solve with objective 9.17649e+06
#
# Presolve removed 22428 rows and 42029 columns
# Presolve time: 0.02s
# Presolved: 12 rows, 13 columns, 27 nonzeros
# Variable types: 0 continuous, 13 integer (13 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.06 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.17649e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.176489346914e+06, best bound 9.175792221337e+06, gap 0.0076%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 24480 rows, 45864 columns and 77760 nonzeros
# Model fingerprint: 0x2c038209
# Variable types: 42588 continuous, 3276 integer (3276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.32179e+06 (0.02s)
# Loaded MIP start from previous solve with objective 9.32179e+06
#
# Presolve removed 24468 rows and 45851 columns
# Presolve time: 0.02s
# Presolved: 12 rows, 13 columns, 27 nonzeros
# Variable types: 0 continuous, 13 integer (13 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.32179e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.321792451584e+06, best bound 9.321096261034e+06, gap 0.0075%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 26520 rows, 49686 columns and 84240 nonzeros
# Model fingerprint: 0x443dcaba
# Variable types: 46137 continuous, 3549 integer (3549 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.45906e+06 (0.03s)
# Loaded MIP start from previous solve with objective 9.45906e+06
#
# Presolve removed 26508 rows and 49673 columns
# Presolve time: 0.02s
# Presolved: 12 rows, 13 columns, 27 nonzeros
# Variable types: 0 continuous, 13 integer (13 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.45906e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.459058331737e+06, best bound 9.458363076216e+06, gap 0.0074%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 28560 rows, 53508 columns and 90720 nonzeros
# Model fingerprint: 0x663709ff
# Variable types: 49686 continuous, 3822 integer (3822 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.59627e+06 (0.03s)
# Loaded MIP start from previous solve with objective 9.59627e+06
#
# Presolve removed 28059 rows and 52940 columns
# Presolve time: 0.01s
# Presolved: 501 rows, 568 columns, 1175 nonzeros
# Variable types: 432 continuous, 136 integer (115 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.59627e+06
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.596273972282e+06, best bound 9.595579675328e+06, gap 0.0072%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 30600 rows, 57330 columns and 97200 nonzeros
# Model fingerprint: 0xb68ae557
# Variable types: 53235 continuous, 4095 integer (4095 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.70947e+06 (0.03s)
# Loaded MIP start from previous solve with objective 9.70947e+06
#
# Presolve removed 29320 rows and 56170 columns
# Presolve time: 0.01s
# Presolved: 1280 rows, 1160 columns, 3825 nonzeros
# Variable types: 940 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.04 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.70947e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.709471069725e+06, best bound 9.708587002426e+06, gap 0.0091%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 32640 rows, 61152 columns and 103680 nonzeros
# Model fingerprint: 0x5f3a0bab
# Variable types: 56784 continuous, 4368 integer (4368 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.82716e+06 (0.03s)
# Loaded MIP start from previous solve with objective 9.82716e+06
#
# Presolve removed 31314 rows and 59953 columns
# Presolve time: 0.00s
# Presolved: 1326 rows, 1199 columns, 3986 nonzeros
# Variable types: 979 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      9827155.22 9826657.23  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.82716e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.827155215091e+06, best bound 9.826657234929e+06, gap 0.0051%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34680 rows, 64974 columns and 110160 nonzeros
# Model fingerprint: 0xa87a0aa7
# Variable types: 60333 continuous, 4641 integer (4641 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 9.93712e+06 (0.02s)
# Loaded MIP start from previous solve with objective 9.93712e+06
#
# Presolve removed 33343 rows and 63765 columns
# Presolve time: 0.01s
# Presolved: 1337 rows, 1209 columns, 4027 nonzeros
# Variable types: 989 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 9.93712e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.937118037240e+06, best bound 9.936427145289e+06, gap 0.0070%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 36720 rows, 68796 columns and 116640 nonzeros
# Model fingerprint: 0x14d25335
# Variable types: 63882 continuous, 4914 integer (4914 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.00357e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.00357e+07
#
# Presolve removed 35375 rows and 67579 columns
# Presolve time: 0.01s
# Presolved: 1345 rows, 1217 columns, 4059 nonzeros
# Variable types: 997 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.00357e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.003572205629e+07, best bound 1.003572205629e+07, gap 0.0000%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 38760 rows, 72618 columns and 123120 nonzeros
# Model fingerprint: 0x72114510
# Variable types: 67431 continuous, 5187 integer (5187 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.01519e+07 (0.02s)
# Loaded MIP start from previous solve with objective 1.01519e+07
#
# Presolve removed 37410 rows and 71396 columns
# Presolve time: 0.01s
# Presolved: 1350 rows, 1222 columns, 4079 nonzeros
# Variable types: 1002 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.01519e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.015187491446e+07, best bound 1.015187491446e+07, gap 0.0000%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 40800 rows, 76440 columns and 129600 nonzeros
# Model fingerprint: 0x56a0c8dc
# Variable types: 70980 continuous, 5460 integer (5460 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.02532e+07 (0.02s)
# Loaded MIP start from previous solve with objective 1.02532e+07
#
# Presolve removed 39419 rows and 75190 columns
# Presolve time: 0.01s
# Presolved: 1381 rows, 1250 columns, 4193 nonzeros
# Variable types: 1030 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.02532e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.025323132025e+07, best bound 1.025323132025e+07, gap 0.0000%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 42840 rows, 80262 columns and 136080 nonzeros
# Model fingerprint: 0x223856ca
# Variable types: 74529 continuous, 5733 integer (5733 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.03564e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.03564e+07
#
# Presolve removed 41443 rows and 78996 columns
# Presolve time: 0.02s
# Presolved: 1397 rows, 1266 columns, 4257 nonzeros
# Variable types: 1046 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.06 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.03564e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.035637269206e+07, best bound 1.035637269206e+07, gap 0.0000%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 44880 rows, 84084 columns and 142560 nonzeros
# Model fingerprint: 0x30784501
# Variable types: 78078 continuous, 6006 integer (6006 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.04368e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.04368e+07
#
# Presolve removed 43474 rows and 82810 columns
# Presolve time: 0.01s
# Presolved: 1406 rows, 1274 columns, 4289 nonzeros
# Variable types: 1054 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.06 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.04368e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.043675217845e+07, best bound 1.043675217845e+07, gap 0.0000%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 46920 rows, 87906 columns and 149040 nonzeros
# Model fingerprint: 0xf92c3a41
# Variable types: 81627 continuous, 6279 integer (6279 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.05119e+07 (0.04s)
# Loaded MIP start from previous solve with objective 1.05119e+07
#
# Presolve removed 45483 rows and 86604 columns
# Presolve time: 0.02s
# Presolved: 1437 rows, 1302 columns, 4401 nonzeros
# Variable types: 1082 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.05119e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.051188781777e+07, best bound 1.051109622088e+07, gap 0.0075%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 48960 rows, 91728 columns and 155520 nonzeros
# Model fingerprint: 0x5aea3146
# Variable types: 85176 continuous, 6552 integer (6552 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.05685e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.05685e+07
#
# Presolve removed 47506 rows and 90410 columns
# Presolve time: 0.01s
# Presolved: 1454 rows, 1318 columns, 4464 nonzeros
# Variable types: 1098 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.05 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.05685e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.056852722178e+07, best bound 1.056852722178e+07, gap 0.0000%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 51000 rows, 95550 columns and 162000 nonzeros
# Model fingerprint: 0xa1de2024
# Variable types: 88725 continuous, 6825 integer (6825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.06216e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.06216e+07
#
# Presolve removed 49546 rows and 94232 columns
# Presolve time: 0.01s
# Presolved: 1454 rows, 1318 columns, 4464 nonzeros
# Variable types: 1098 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.06216e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.062164192874e+07, best bound 1.062164192874e+07, gap 0.0000%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 53040 rows, 99372 columns and 168480 nonzeros
# Model fingerprint: 0x74a89c14
# Variable types: 92274 continuous, 7098 integer (7098 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.06748e+07 (0.02s)
# Loaded MIP start from previous solve with objective 1.06748e+07
#
# Presolve removed 51586 rows and 98054 columns
# Presolve time: 0.01s
# Presolved: 1454 rows, 1318 columns, 4464 nonzeros
# Variable types: 1098 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.06 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.06748e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.067475663570e+07, best bound 1.067475663570e+07, gap 0.0000%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 55080 rows, 103194 columns and 174960 nonzeros
# Model fingerprint: 0x455ca8bb
# Variable types: 95823 continuous, 7371 integer (7371 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.07279e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.07279e+07
#
# Presolve removed 53615 rows and 101865 columns
# Presolve time: 0.02s
# Presolved: 1465 rows, 1329 columns, 4508 nonzeros
# Variable types: 1109 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.07279e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072787134266e+07, best bound 1.072787134266e+07, gap 0.0000%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 57120 rows, 107016 columns and 181440 nonzeros
# Model fingerprint: 0xc5c0dfa3
# Variable types: 99372 continuous, 7644 integer (7644 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.0773e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.0773e+07
#
# Presolve removed 55653 rows and 105685 columns
# Presolve time: 0.02s
# Presolved: 1467 rows, 1331 columns, 4516 nonzeros
# Variable types: 1111 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.07 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.0773e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.077301319395e+07, best bound 1.077218402262e+07, gap 0.0077%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 59160 rows, 110838 columns and 187920 nonzeros
# Model fingerprint: 0x8515b350
# Variable types: 102921 continuous, 7917 integer (7917 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.08166e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.08166e+07
#
# Presolve removed 57693 rows and 109507 columns
# Presolve time: 0.02s
# Presolved: 1467 rows, 1331 columns, 4516 nonzeros
# Variable types: 1111 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.08166e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.081664403219e+07, best bound 1.081584256346e+07, gap 0.0074%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 61200 rows, 114660 columns and 194400 nonzeros
# Model fingerprint: 0xcba92198
# Variable types: 106470 continuous, 8190 integer (8190 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.08581e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.08581e+07
#
# Presolve removed 59724 rows and 113321 columns
# Presolve time: 0.02s
# Presolved: 1476 rows, 1339 columns, 4549 nonzeros
# Variable types: 1119 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.08581e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.085812122017e+07, best bound 1.085734745404e+07, gap 0.0071%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 63240 rows, 118482 columns and 200880 nonzeros
# Model fingerprint: 0xdeabd915
# Variable types: 110019 continuous, 8463 integer (8463 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.08977e+07 (0.04s)
# Loaded MIP start from previous solve with objective 1.08977e+07
#
# Presolve removed 61764 rows and 117143 columns
# Presolve time: 0.02s
# Presolved: 1476 rows, 1339 columns, 4549 nonzeros
# Variable types: 1119 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.08977e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.089771580869e+07, best bound 1.089697125769e+07, gap 0.0068%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 65280 rows, 122304 columns and 207360 nonzeros
# Model fingerprint: 0x9d42a4de
# Variable types: 113568 continuous, 8736 integer (8736 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.09367e+07 (0.03s)
# Loaded MIP start from previous solve with objective 1.09367e+07
#
# Presolve removed 63798 rows and 120959 columns
# Presolve time: 0.02s
# Presolved: 1482 rows, 1345 columns, 4573 nonzeros
# Variable types: 1125 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.09367e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.093671573971e+07, best bound 1.093671573971e+07, gap 0.0000%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 67320 rows, 126126 columns and 213840 nonzeros
# Model fingerprint: 0xaef6cec8
# Variable types: 117117 continuous, 9009 integer (9009 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.09761e+07 (0.05s)
# Loaded MIP start from previous solve with objective 1.09761e+07
#
# Presolve removed 65825 rows and 124769 columns
# Presolve time: 0.02s
# Presolved: 1495 rows, 1357 columns, 4621 nonzeros
# Variable types: 1137 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      1.0976e+07 1.0975e+07  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.09 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.09761e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.097608472462e+07, best bound 1.097539760724e+07, gap 0.0063%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69360 rows, 129948 columns and 220320 nonzeros
# Model fingerprint: 0xdba14c70
# Variable types: 120666 continuous, 9282 integer (9282 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# MIP start from previous solve produced solution with objective 1.10123e+07 (0.04s)
# Loaded MIP start from previous solve with objective 1.10123e+07
#
# Presolve removed 67861 rows and 128587 columns
# Presolve time: 0.02s
# Presolved: 1499 rows, 1361 columns, 4637 nonzeros
# Variable types: 1141 continuous, 220 integer (220 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      1.1012e+07 1.1012e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.10123e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.101231724743e+07, best bound 1.101166924743e+07, gap 0.0059%
# Iteration: 35
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 71400 rows, 133770 columns and 226800 nonzeros
# Model fingerprint: 0x411d8669
# Variable types: 124215 continuous, 9555 integer (9555 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.10493e+07 (0.04s)
# Loaded MIP start from previous solve with objective 1.10493e+07
#
# Presolve removed 69896 rows and 132404 columns
# Presolve time: 0.03s
# Presolved: 1504 rows, 1366 columns, 4657 nonzeros
# Variable types: 1146 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.10 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.10493e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.104929036947e+07, best bound 1.104929036947e+07, gap 0.0000%
# Iteration: 36
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 73440 rows, 137592 columns and 233280 nonzeros
# Model fingerprint: 0x3e7e1135
# Variable types: 127764 continuous, 9828 integer (9828 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.10837e+07 (0.04s)
# Loaded MIP start from previous solve with objective 1.10837e+07
#
# Presolve removed 71936 rows and 136226 columns
# Presolve time: 0.01s
# Presolved: 1504 rows, 1366 columns, 4657 nonzeros
# Variable types: 1146 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.09 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.10837e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.108368520336e+07, best bound 1.108368520336e+07, gap 0.0000%
# Iteration: 37
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 75480 rows, 141414 columns and 239760 nonzeros
# Model fingerprint: 0xa665df76
# Variable types: 131313 continuous, 10101 integer (10101 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.11166e+07 (0.05s)
# Loaded MIP start from previous solve with objective 1.11166e+07
#
# Presolve removed 73976 rows and 140048 columns
# Presolve time: 0.02s
# Presolved: 1504 rows, 1366 columns, 4657 nonzeros
# Variable types: 1146 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.10 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.11166e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.111658781308e+07, best bound 1.111658781308e+07, gap 0.0000%
# Iteration: 38
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 77520 rows, 145236 columns and 246240 nonzeros
# Model fingerprint: 0xe6b30c48
# Variable types: 134862 continuous, 10374 integer (10374 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.11471e+07 (0.05s)
# Loaded MIP start from previous solve with objective 1.11471e+07
#
# Presolve removed 76006 rows and 143861 columns
# Presolve time: 0.02s
# Presolved: 1514 rows, 1375 columns, 4693 nonzeros
# Variable types: 1155 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.09 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.11471e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.114714892063e+07, best bound 1.114714892063e+07, gap 0.0000%
# Iteration: 39
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 79560 rows, 149058 columns and 252720 nonzeros
# Model fingerprint: 0xa520ca1b
# Variable types: 138411 continuous, 10647 integer (10647 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [6e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.11784e+07 (0.05s)
# Loaded MIP start from previous solve with objective 1.11784e+07
#
# Presolve removed 78056 rows and 147692 columns
# Presolve time: 0.03s
# Presolved: 1504 rows, 1366 columns, 4657 nonzeros
# Variable types: 1146 continuous, 220 integer (220 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.10 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.11784e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.117835432829e+07, best bound 1.117835432829e+07, gap 0.0000%

# %%
sheet_name = sheet_list[2]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-20-24 (1)
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 6960 rows, 13650 columns and 24468 nonzeros
# Model fingerprint: 0x4b359269
# Variable types: 13125 continuous, 525 integer (525 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.283021e+07
# Presolve removed 6873 rows and 13553 columns
# Presolve time: 0.02s
# Presolved: 87 rows, 97 columns, 238 nonzeros
# Found heuristic solution: objective 2977679.0000
# Variable types: 56 continuous, 41 integer (41 binary)
#
# Root relaxation: objective 2.924927e+06, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2924927.0000 2924927.00  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.02 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 2.92493e+06 2.97768e+06 1.28302e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.924927000000e+06, best bound 2.924927000000e+06, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 13920 rows, 27300 columns and 48936 nonzeros
# Model fingerprint: 0x92495c44
# Variable types: 26250 continuous, 1050 integer (1050 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.06356e+06 (0.03s)
# Loaded MIP start from previous solve with objective 3.06356e+06
#
# Presolve removed 13830 rows and 27202 columns
# Presolve time: 0.03s
# Presolved: 90 rows, 98 columns, 244 nonzeros
# Variable types: 52 continuous, 46 integer (46 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3063560.46 3063560.46  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.07 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.06356e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.063560463797e+06, best bound 3.063560463797e+06, gap 0.0000%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 20880 rows, 40950 columns and 73404 nonzeros
# Model fingerprint: 0xc508ca24
# Variable types: 39375 continuous, 1575 integer (1575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.21928e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.21928e+06
#
# Presolve removed 20780 rows and 40850 columns
# Presolve time: 0.03s
# Presolved: 100 rows, 100 columns, 260 nonzeros
# Variable types: 88 continuous, 12 integer (12 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      3219282.58 3219124.43  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.08 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.21928e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.219282580328e+06, best bound 3.219124432806e+06, gap 0.0049%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 27840 rows, 54600 columns and 97872 nonzeros
# Model fingerprint: 0xbb5b0e21
# Variable types: 52500 continuous, 2100 integer (2100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.36754e+06 (0.05s)
# Loaded MIP start from previous solve with objective 3.36754e+06
#
# Presolve removed 26966 rows and 53686 columns
# Presolve time: 0.03s
# Presolved: 874 rows, 914 columns, 2258 nonzeros
# Variable types: 283 continuous, 631 integer (631 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      3367543.06 3367452.88  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.10 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.36754e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.367543062613e+06, best bound 3.367452875875e+06, gap 0.0027%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34800 rows, 68250 columns and 122340 nonzeros
# Model fingerprint: 0x511f5fce
# Variable types: 65625 continuous, 2625 integer (2625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.50204e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.50204e+06
#
# Presolve removed 31126 rows and 64632 columns
# Presolve time: 0.01s
# Presolved: 3674 rows, 3618 columns, 12584 nonzeros
# Variable types: 3170 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3502038.17 3502038.17  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.50204e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.502038170654e+06, best bound 3.502038170654e+06, gap 0.0000%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 41760 rows, 81900 columns and 146808 nonzeros
# Model fingerprint: 0xf2cbad9d
# Variable types: 78750 continuous, 3150 integer (3150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.63971e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.63971e+06
#
# Presolve removed 38064 rows and 78263 columns
# Presolve time: 0.01s
# Presolved: 3696 rows, 3637 columns, 12658 nonzeros
# Variable types: 3189 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3639709.49 3639709.49  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.09 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.63971e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.639709486612e+06, best bound 3.639709486612e+06, gap 0.0000%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 48720 rows, 95550 columns and 171276 nonzeros
# Model fingerprint: 0x4c45d5e3
# Variable types: 91875 continuous, 3675 integer (3675 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.76304e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.76304e+06
#
# Presolve removed 45004 rows and 91897 columns
# Presolve time: 0.02s
# Presolved: 3716 rows, 3653 columns, 12725 nonzeros
# Variable types: 3205 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3763044.78 3763044.78  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.10 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.76304e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.763044782852e+06, best bound 3.763044782852e+06, gap 0.0000%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 55680 rows, 109200 columns and 195744 nonzeros
# Model fingerprint: 0x45bb25b2
# Variable types: 105000 continuous, 4200 integer (4200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.87085e+06 (0.05s)
# Loaded MIP start from previous solve with objective 3.87085e+06
#
# Presolve removed 51947 rows and 105532 columns
# Presolve time: 0.02s
# Presolved: 3733 rows, 3668 columns, 12785 nonzeros
# Variable types: 3220 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3870847.52 3870847.52  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.11 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.87085e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.870847523635e+06, best bound 3.870847523635e+06, gap 0.0000%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 62640 rows, 122850 columns and 220212 nonzeros
# Model fingerprint: 0xe56305f3
# Variable types: 118125 continuous, 4725 integer (4725 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.98494e+06 (0.05s)
# Loaded MIP start from previous solve with objective 3.98494e+06
#
# Presolve removed 58904 rows and 119179 columns
# Presolve time: 0.02s
# Presolved: 3736 rows, 3671 columns, 12795 nonzeros
# Variable types: 3223 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      3984938.68 3984827.51  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.11 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.98494e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.984938675469e+06, best bound 3.984827512143e+06, gap 0.0028%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69600 rows, 136500 columns and 244680 nonzeros
# Model fingerprint: 0xbc239c96
# Variable types: 131250 continuous, 5250 integer (5250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.11997e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.11997e+06
#
# Presolve removed 65848 rows and 132813 columns
# Presolve time: 0.02s
# Presolved: 3752 rows, 3687 columns, 12859 nonzeros
# Variable types: 3239 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4119972.12 4119972.12  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.13 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.11997e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.119972115503e+06, best bound 4.119972115503e+06, gap 0.0000%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 76560 rows, 150150 columns and 269148 nonzeros
# Model fingerprint: 0x160645b7
# Variable types: 144375 continuous, 5775 integer (5775 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.23481e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.23481e+06
#
# Presolve removed 72790 rows and 146447 columns
# Presolve time: 0.02s
# Presolved: 3770 rows, 3703 columns, 12924 nonzeros
# Variable types: 3255 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4234812.76 4234573.16  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.13 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.23481e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.234812763963e+06, best bound 4.234573155953e+06, gap 0.0057%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 83520 rows, 163800 columns and 293616 nonzeros
# Model fingerprint: 0xefa336b8
# Variable types: 157500 continuous, 6300 integer (6300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.33577e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.33577e+06
#
# Presolve removed 79737 rows and 160085 columns
# Presolve time: 0.03s
# Presolved: 3783 rows, 3715 columns, 12968 nonzeros
# Variable types: 3267 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4335770.96 4335535.11  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.14 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.33577e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.335770962048e+06, best bound 4.335535114171e+06, gap 0.0054%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 90480 rows, 177450 columns and 318084 nonzeros
# Model fingerprint: 0xc79b7466
# Variable types: 170625 continuous, 6825 integer (6825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.44011e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.44011e+06
#
# Presolve removed 86675 rows and 173715 columns
# Presolve time: 0.03s
# Presolved: 3805 rows, 3735 columns, 13050 nonzeros
# Variable types: 3287 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4440114.95 4439737.58  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.16 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.44011e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.440114953750e+06, best bound 4.439737580192e+06, gap 0.0085%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 97440 rows, 191100 columns and 342552 nonzeros
# Model fingerprint: 0x1ea620fb
# Variable types: 183750 continuous, 7350 integer (7350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.54092e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.54092e+06
#
# Presolve removed 93626 rows and 187356 columns
# Presolve time: 0.03s
# Presolved: 3814 rows, 3744 columns, 13086 nonzeros
# Variable types: 3296 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4540923.82 4540739.78  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.16 seconds (0.13 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.54092e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.540923820155e+06, best bound 4.540739776074e+06, gap 0.0041%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 104400 rows, 204750 columns and 367020 nonzeros
# Model fingerprint: 0xad92a59c
# Variable types: 196875 continuous, 7875 integer (7875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.63167e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.63167e+06
#
# Presolve removed 100562 rows and 200984 columns
# Presolve time: 0.04s
# Presolved: 3838 rows, 3766 columns, 13176 nonzeros
# Variable types: 3318 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4631672.43 4631385.46  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.18 seconds (0.14 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.63167e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.631672429595e+06, best bound 4.631385459399e+06, gap 0.0062%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 111360 rows, 218400 columns and 391488 nonzeros
# Model fingerprint: 0x76ada030
# Variable types: 210000 continuous, 8400 integer (8400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.68667e+06 (0.08s)
# Loaded MIP start from previous solve with objective 4.68667e+06
#
# Presolve removed 107517 rows and 214630 columns
# Presolve time: 0.04s
# Presolved: 3843 rows, 3770 columns, 13193 nonzeros
# Variable types: 3322 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4686672.60 4686672.60  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.18 seconds (0.14 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.68667e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.686672595410e+06, best bound 4.686672595410e+06, gap 0.0000%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 118320 rows, 232050 columns and 415956 nonzeros
# Model fingerprint: 0x34cec9cf
# Variable types: 223125 continuous, 8925 integer (8925 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.74164e+06 (0.08s)
# Loaded MIP start from previous solve with objective 4.74164e+06
#
# Presolve removed 114472 rows and 228275 columns
# Presolve time: 0.04s
# Presolved: 3848 rows, 3775 columns, 13213 nonzeros
# Variable types: 3327 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4741640.48 4741347.28  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.19 seconds (0.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.74164e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.741640477359e+06, best bound 4.741347282032e+06, gap 0.0062%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 125280 rows, 245700 columns and 440424 nonzeros
# Model fingerprint: 0x25e347fc
# Variable types: 236250 continuous, 9450 integer (9450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.79071e+06 (0.09s)
# Loaded MIP start from previous solve with objective 4.79071e+06
#
# Presolve removed 121414 rows and 241911 columns
# Presolve time: 0.05s
# Presolved: 3866 rows, 3789 columns, 13273 nonzeros
# Variable types: 3341 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4790706.49 4790341.54  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.19 seconds (0.16 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.79071e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.790706491590e+06, best bound 4.790341536320e+06, gap 0.0076%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 132240 rows, 259350 columns and 464892 nonzeros
# Model fingerprint: 0xcac0ac26
# Variable types: 249375 continuous, 9975 integer (9975 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.84663e+06 (0.09s)
# Loaded MIP start from previous solve with objective 4.84663e+06
#
# Presolve removed 128367 rows and 255554 columns
# Presolve time: 0.04s
# Presolved: 3873 rows, 3796 columns, 13301 nonzeros
# Variable types: 3348 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4846625.79 4846358.39  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.21 seconds (0.16 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.84663e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.846625790508e+06, best bound 4.846358386056e+06, gap 0.0055%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 139200 rows, 273000 columns and 489360 nonzeros
# Model fingerprint: 0x88cf3bba
# Variable types: 262500 continuous, 10500 integer (10500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.90116e+06 (0.10s)
# Loaded MIP start from previous solve with objective 4.90116e+06
#
# Presolve removed 135312 rows and 269191 columns
# Presolve time: 0.05s
# Presolved: 3888 rows, 3809 columns, 13354 nonzeros
# Variable types: 3361 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4901158.65 4900923.51  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.22 seconds (0.17 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.90116e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.901158652590e+06, best bound 4.900923506048e+06, gap 0.0048%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 146160 rows, 286650 columns and 513828 nonzeros
# Model fingerprint: 0x7e4c978d
# Variable types: 275625 continuous, 11025 integer (11025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.94427e+06 (0.10s)
# Loaded MIP start from previous solve with objective 4.94427e+06
#
# Presolve removed 142272 rows and 282841 columns
# Presolve time: 0.05s
# Presolved: 3888 rows, 3809 columns, 13354 nonzeros
# Variable types: 3361 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4944266.58 4943902.88  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.22 seconds (0.18 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.94427e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.944266579546e+06, best bound 4.943902876594e+06, gap 0.0074%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 153120 rows, 300300 columns and 538296 nonzeros
# Model fingerprint: 0xa8b11f3f
# Variable types: 288750 continuous, 11550 integer (11550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.97907e+06 (0.10s)
# Loaded MIP start from previous solve with objective 4.97907e+06
#
# Presolve removed 149231 rows and 296490 columns
# Presolve time: 0.05s
# Presolved: 3889 rows, 3810 columns, 13358 nonzeros
# Variable types: 3362 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4979069.81 4978622.92  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.22 seconds (0.19 work units)
# Thread count was 16 (of 16 available processors)
# Solution count 1: 4.97907e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.979069811022e+06, best bound 4.978622916360e+06, gap 0.0090%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 160080 rows, 313950 columns and 562764 nonzeros
# Model fingerprint: 0x26a26de8
# Variable types: 301875 continuous, 12075 integer (12075 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.99706e+06 (0.11s)
# Loaded MIP start from previous solve with objective 4.99706e+06
#
# Presolve removed 156187 rows and 310136 columns
# Presolve time: 0.06s
# Presolved: 3893 rows, 3814 columns, 13373 nonzeros
# Variable types: 3366 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4997057.41 4996694.30  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.24 seconds (0.19 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.99706e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.997057406772e+06, best bound 4.996694302656e+06, gap 0.0073%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 167040 rows, 327600 columns and 587232 nonzeros
# Model fingerprint: 0x840f0ad9
# Variable types: 315000 continuous, 12600 integer (12600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.01634e+06 (0.10s)
# Loaded MIP start from previous solve with objective 5.01634e+06
#
# Presolve removed 163140 rows and 323782 columns
# Presolve time: 0.05s
# Presolved: 3900 rows, 3818 columns, 13392 nonzeros
# Variable types: 3370 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5016335.73 5016041.71  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.01634e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.016335728552e+06, best bound 5.016041709514e+06, gap 0.0059%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 174000 rows, 341250 columns and 611700 nonzeros
# Model fingerprint: 0x122bad77
# Variable types: 328125 continuous, 13125 integer (13125 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.03219e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.03219e+06
#
# Presolve removed 170094 rows and 337426 columns
# Presolve time: 0.06s
# Presolved: 3906 rows, 3824 columns, 13415 nonzeros
# Variable types: 3376 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5032185.42 5031953.12  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.27 seconds (0.21 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.03219e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.032185415264e+06, best bound 5.031953116776e+06, gap 0.0046%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 180960 rows, 354900 columns and 636168 nonzeros
# Model fingerprint: 0x11eb58ab
# Variable types: 341250 continuous, 13650 integer (13650 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.04202e+06 (0.11s)
# Loaded MIP start from previous solve with objective 5.04202e+06
#
# Presolve removed 177054 rows and 351076 columns
# Presolve time: 0.07s
# Presolved: 3906 rows, 3824 columns, 13415 nonzeros
# Variable types: 3376 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5042015.29 5041783.35  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.26 seconds (0.21 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.04202e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.042015286850e+06, best bound 5.041783349382e+06, gap 0.0046%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 187920 rows, 368550 columns and 660636 nonzeros
# Model fingerprint: 0xd85f0e58
# Variable types: 354375 continuous, 14175 integer (14175 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.05935e+06 (0.11s)
# Loaded MIP start from previous solve with objective 5.05935e+06
#
# Presolve removed 184014 rows and 364726 columns
# Presolve time: 0.06s
# Presolved: 3906 rows, 3824 columns, 13415 nonzeros
# Variable types: 3376 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5059349.40 5059117.83  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.26 seconds (0.22 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.05935e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.059349402784e+06, best bound 5.059117826336e+06, gap 0.0046%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 194880 rows, 382200 columns and 685104 nonzeros
# Model fingerprint: 0x5065ef2b
# Variable types: 367500 continuous, 14700 integer (14700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.06837e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.06837e+06
#
# Presolve removed 190972 rows and 378374 columns
# Presolve time: 0.07s
# Presolved: 3908 rows, 3826 columns, 13423 nonzeros
# Variable types: 3378 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5068371.93 5068140.71  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.26 seconds (0.23 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.06837e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.068371930183e+06, best bound 5.068140714754e+06, gap 0.0046%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 201840 rows, 395850 columns and 709572 nonzeros
# Model fingerprint: 0x2d64d752
# Variable types: 380625 continuous, 15225 integer (15225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.07173e+06 (0.13s)
# Loaded MIP start from previous solve with objective 5.07173e+06
#
# Presolve removed 197931 rows and 392023 columns
# Presolve time: 0.07s
# Presolved: 3909 rows, 3827 columns, 13427 nonzeros
# Variable types: 3379 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5071729.37 5071368.21  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.28 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.07173e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.071729374753e+06, best bound 5.071368206915e+06, gap 0.0071%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208800 rows, 409500 columns and 734040 nonzeros
# Model fingerprint: 0x3d8839e1
# Variable types: 393750 continuous, 15750 integer (15750 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.08263e+06 (0.13s)
# Loaded MIP start from previous solve with objective 5.08263e+06
#
# Presolve removed 204891 rows and 405673 columns
# Presolve time: 0.08s
# Presolved: 3909 rows, 3827 columns, 13427 nonzeros
# Variable types: 3379 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5082629.81 5082399.32  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.28 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.08263e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.082629814366e+06, best bound 5.082399320977e+06, gap 0.0045%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 215760 rows, 423150 columns and 758508 nonzeros
# Model fingerprint: 0xf7b82a3e
# Variable types: 406875 continuous, 16275 integer (16275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.09448e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.09448e+06
#
# Presolve removed 211851 rows and 419323 columns
# Presolve time: 0.08s
# Presolved: 3909 rows, 3827 columns, 13427 nonzeros
# Variable types: 3379 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5094482.50 5094337.62  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.31 seconds (0.25 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.09448e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.094482500709e+06, best bound 5.094337624211e+06, gap 0.0028%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 222720 rows, 436800 columns and 782976 nonzeros
# Model fingerprint: 0x77b404b7
# Variable types: 420000 continuous, 16800 integer (16800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.102e+06 (0.13s)
# Loaded MIP start from previous solve with objective 5.102e+06
#
# Presolve removed 218808 rows and 432970 columns
# Presolve time: 0.08s
# Presolved: 3912 rows, 3830 columns, 13439 nonzeros
# Variable types: 3382 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5101995.51 5101606.48  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.29 seconds (0.26 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.102e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.101995505393e+06, best bound 5.101606480161e+06, gap 0.0076%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 229680 rows, 450450 columns and 807444 nonzeros
# Model fingerprint: 0x80b34b11
# Variable types: 433125 continuous, 17325 integer (17325 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.11271e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.11271e+06
#
# Presolve removed 225768 rows and 446620 columns
# Presolve time: 0.08s
# Presolved: 3912 rows, 3830 columns, 13439 nonzeros
# Variable types: 3382 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      5112712.08 5112712.08  0.00%     -    0s
# Explored 1 nodes (5 simplex iterations) in 0.31 seconds (0.26 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.11271e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.112712081343e+06, best bound 5.112712081343e+06, gap 0.0000%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 236640 rows, 464100 columns and 831912 nonzeros
# Model fingerprint: 0xd2be02bc
# Variable types: 446250 continuous, 17850 integer (17850 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.1141e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.1141e+06
#
# Presolve removed 232726 rows and 460268 columns
# Presolve time: 0.08s
# Presolved: 3914 rows, 3832 columns, 13447 nonzeros
# Variable types: 3384 continuous, 448 integer (448 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5114096.12 5113926.46  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.31 seconds (0.27 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.1141e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.114096116430e+06, best bound 5.113926461085e+06, gap 0.0033%
# Iteration: 35
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 243600 rows, 477750 columns and 856380 nonzeros
# Model fingerprint: 0xc77812e2
# Variable types: 459375 continuous, 18375 integer (18375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [3e+01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.12561e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.12561e+06
#
# Presolve removed 239686 rows and 473918 columns
# Presolve time: 0.08s
# Presolved: 3914 rows, 3832 columns, 13447 nonzeros
# Variable types: 3384 continuous, 448 integer (448 binary)
#
# Root relaxation: cutoff, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      5125614.42 5125614.42  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.33 seconds (0.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.12561e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.125614416230e+06, best bound 5.125614416230e+06, gap 0.0000%

# %%
sheet_name = sheet_list[3]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-20-24 (2)
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 6960 rows, 13650 columns and 24466 nonzeros
# Model fingerprint: 0xd0fafea2
# Variable types: 13125 continuous, 525 integer (525 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.608520e+07
# Presolve removed 6870 rows and 13559 columns
# Presolve time: 0.01s
# Presolved: 90 rows, 91 columns, 236 nonzeros
# Found heuristic solution: objective 4617714.0000
# Variable types: 80 continuous, 11 integer (11 binary)
#
# Root relaxation: objective 3.535102e+06, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3535102.0000 3535102.00  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 3.5351e+06 4.61771e+06 1.60852e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.535102000000e+06, best bound 3.535102000000e+06, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 13920 rows, 27300 columns and 48932 nonzeros
# Model fingerprint: 0x8b7f7e9f
# Variable types: 26250 continuous, 1050 integer (1050 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.63167e+06 (0.03s)
# Loaded MIP start from previous solve with objective 3.63167e+06
#
# Presolve removed 13811 rows and 27186 columns
# Presolve time: 0.02s
# Presolved: 109 rows, 114 columns, 295 nonzeros
# Variable types: 50 continuous, 64 integer (64 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3631671.80 3631671.80  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.07 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.63167e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.631671804967e+06, best bound 3.631671804967e+06, gap 0.0000%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 20880 rows, 40950 columns and 73398 nonzeros
# Model fingerprint: 0x5a8ae8c8
# Variable types: 39375 continuous, 1575 integer (1575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.73104e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.73104e+06
#
# Presolve removed 20771 rows and 40836 columns
# Presolve time: 0.03s
# Presolved: 109 rows, 114 columns, 295 nonzeros
# Variable types: 50 continuous, 64 integer (64 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3731036.27 3731036.27  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.09 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.73104e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.731036273469e+06, best bound 3.731036273469e+06, gap 0.0000%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 27840 rows, 54600 columns and 97864 nonzeros
# Model fingerprint: 0x465cc126
# Variable types: 52500 continuous, 2100 integer (2100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.82273e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.82273e+06
#
# Presolve removed 27024 rows and 53723 columns
# Presolve time: 0.03s
# Presolved: 816 rows, 877 columns, 2092 nonzeros
# Variable types: 155 continuous, 722 integer (722 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.82273e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.822730757330e+06, best bound 3.822730757330e+06, gap 0.0000%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34800 rows, 68250 columns and 122330 nonzeros
# Model fingerprint: 0x3f47d3af
# Variable types: 65625 continuous, 2625 integer (2625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.91259e+06 (0.04s)
# Loaded MIP start from previous solve with objective 3.91259e+06
#
# Presolve removed 32585 rows and 66077 columns
# Presolve time: 0.01s
# Presolved: 2215 rows, 2173 columns, 7261 nonzeros
# Variable types: 1895 continuous, 278 integer (278 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      3912585.62 3912411.90  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.08 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.91259e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.912585619587e+06, best bound 3.912411896753e+06, gap 0.0044%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 41760 rows, 81900 columns and 146796 nonzeros
# Model fingerprint: 0x278c0ee9
# Variable types: 78750 continuous, 3150 integer (3150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.99994e+06 (0.05s)
# Loaded MIP start from previous solve with objective 3.99994e+06
#
# Presolve removed 37917 rows and 78102 columns
# Presolve time: 0.01s
# Presolved: 3843 rows, 3798 columns, 13259 nonzeros
# Variable types: 3352 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      3999939.45 3999939.45  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.09 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.99994e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.999939450540e+06, best bound 3.999939450540e+06, gap 0.0000%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 48720 rows, 95550 columns and 171262 nonzeros
# Model fingerprint: 0x29ca7ad5
# Variable types: 91875 continuous, 3675 integer (3675 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [4e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.08405e+06 (0.05s)
# Loaded MIP start from previous solve with objective 4.08405e+06
#
# Presolve removed 44870 rows and 91746 columns
# Presolve time: 0.02s
# Presolved: 3850 rows, 3804 columns, 13284 nonzeros
# Variable types: 3358 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4084046.73 4084046.73  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.10 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.08405e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.084046733789e+06, best bound 4.084046733789e+06, gap 0.0000%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 55680 rows, 109200 columns and 195728 nonzeros
# Model fingerprint: 0x64c28b84
# Variable types: 105000 continuous, 4200 integer (4200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.16229e+06 (0.05s)
# Loaded MIP start from previous solve with objective 4.16229e+06
#
# Presolve removed 51821 rows and 105388 columns
# Presolve time: 0.02s
# Presolved: 3859 rows, 3812 columns, 13316 nonzeros
# Variable types: 3366 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4162294.99 4162121.40  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.11 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.16229e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.162294992232e+06, best bound 4.162121398215e+06, gap 0.0042%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 62640 rows, 122850 columns and 220194 nonzeros
# Model fingerprint: 0xf56eb5ce
# Variable types: 118125 continuous, 4725 integer (4725 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.23995e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.23995e+06
#
# Presolve removed 58763 rows and 119023 columns
# Presolve time: 0.02s
# Presolved: 3877 rows, 3827 columns, 13376 nonzeros
# Variable types: 3381 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4239948.54 4239948.54  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.12 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.23995e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.239948535143e+06, best bound 4.239948535143e+06, gap 0.0000%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69600 rows, 136500 columns and 244660 nonzeros
# Model fingerprint: 0xd2f81440
# Variable types: 131250 continuous, 5250 integer (5250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.31137e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.31137e+06
#
# Presolve removed 65707 rows and 132660 columns
# Presolve time: 0.02s
# Presolved: 3893 rows, 3840 columns, 13430 nonzeros
# Variable types: 3394 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4311370.99 4311370.99  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.13 seconds (0.10 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.31137e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.311370986351e+06, best bound 4.311370986351e+06, gap 0.0000%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 76560 rows, 150150 columns and 269126 nonzeros
# Model fingerprint: 0x56e94a9a
# Variable types: 144375 continuous, 5775 integer (5775 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.38137e+06 (0.06s)
# Loaded MIP start from previous solve with objective 4.38137e+06
#
# Presolve removed 72628 rows and 146280 columns
# Presolve time: 0.03s
# Presolved: 3932 rows, 3870 columns, 13554 nonzeros
# Variable types: 3424 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4381369.61 4381045.84  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.13 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.38137e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.381369606526e+06, best bound 4.381045840880e+06, gap 0.0074%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 83520 rows, 163800 columns and 293592 nonzeros
# Model fingerprint: 0x59741127
# Variable types: 157500 continuous, 6300 integer (6300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.45856e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.45856e+06
#
# Presolve removed 79588 rows and 159930 columns
# Presolve time: 0.04s
# Presolved: 3932 rows, 3870 columns, 13554 nonzeros
# Variable types: 3424 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4458563.38 4458563.38  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.16 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.45856e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.458563384886e+06, best bound 4.458563384886e+06, gap 0.0000%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 90480 rows, 177450 columns and 318058 nonzeros
# Model fingerprint: 0x2b5ac5fc
# Variable types: 170625 continuous, 6825 integer (6825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.53398e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.53398e+06
#
# Presolve removed 86546 rows and 173578 columns
# Presolve time: 0.04s
# Presolved: 3934 rows, 3872 columns, 13562 nonzeros
# Variable types: 3426 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4533975.51 4533975.51  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.16 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.53398e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.533975509036e+06, best bound 4.533975509036e+06, gap 0.0000%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 97440 rows, 191100 columns and 342524 nonzeros
# Model fingerprint: 0x82a1494d
# Variable types: 183750 continuous, 7350 integer (7350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.61135e+06 (0.08s)
# Loaded MIP start from previous solve with objective 4.61135e+06
#
# Presolve removed 93491 rows and 187216 columns
# Presolve time: 0.02s
# Presolved: 3949 rows, 3884 columns, 13609 nonzeros
# Variable types: 3438 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      4611352.62 4611352.62  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.16 seconds (0.13 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.61135e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.611352622436e+06, best bound 4.611352622436e+06, gap 0.0000%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 104400 rows, 204750 columns and 366990 nonzeros
# Model fingerprint: 0x6dbe4964
# Variable types: 196875 continuous, 7875 integer (7875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.68304e+06 (0.07s)
# Loaded MIP start from previous solve with objective 4.68304e+06
#
# Presolve removed 100443 rows and 200858 columns
# Presolve time: 0.04s
# Presolved: 3957 rows, 3892 columns, 13637 nonzeros
# Variable types: 3446 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4683035.49 4682699.18  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.16 seconds (0.13 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.68304e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.683035489067e+06, best bound 4.682699179704e+06, gap 0.0072%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 111360 rows, 218400 columns and 391456 nonzeros
# Model fingerprint: 0xdc9b3f9c
# Variable types: 210000 continuous, 8400 integer (8400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.73983e+06 (0.08s)
# Loaded MIP start from previous solve with objective 4.73983e+06
#
# Presolve removed 107377 rows and 214489 columns
# Presolve time: 0.04s
# Presolved: 3983 rows, 3911 columns, 13719 nonzeros
# Variable types: 3465 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4739827.19 4739795.88  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.18 seconds (0.14 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.73983e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.739827185230e+06, best bound 4.739795876844e+06, gap 0.0007%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 118320 rows, 232050 columns and 415922 nonzeros
# Model fingerprint: 0xa01830f7
# Variable types: 223125 continuous, 8925 integer (8925 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.78455e+06 (0.08s)
# Loaded MIP start from previous solve with objective 4.78455e+06
#
# Presolve removed 114337 rows and 228139 columns
# Presolve time: 0.05s
# Presolved: 3983 rows, 3911 columns, 13719 nonzeros
# Variable types: 3465 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4784547.22 4784170.80  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.20 seconds (0.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.78455e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.784547220726e+06, best bound 4.784170803176e+06, gap 0.0079%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 125280 rows, 245700 columns and 440388 nonzeros
# Model fingerprint: 0x094ed4b9
# Variable types: 236250 continuous, 9450 integer (9450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.8391e+06 (0.09s)
# Loaded MIP start from previous solve with objective 4.8391e+06
#
# Presolve removed 121288 rows and 241781 columns
# Presolve time: 0.04s
# Presolved: 3992 rows, 3919 columns, 13752 nonzeros
# Variable types: 3473 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4839096.32 4839047.18  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.19 seconds (0.16 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.8391e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.839096320472e+06, best bound 4.839047184587e+06, gap 0.0010%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 132240 rows, 259350 columns and 464854 nonzeros
# Model fingerprint: 0xc6068fd5
# Variable types: 249375 continuous, 9975 integer (9975 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [3e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.887e+06 (0.09s)
# Loaded MIP start from previous solve with objective 4.887e+06
#
# Presolve removed 128243 rows and 255426 columns
# Presolve time: 0.05s
# Presolved: 3997 rows, 3924 columns, 13772 nonzeros
# Variable types: 3478 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4886999.35 4886949.50  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.21 seconds (0.17 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.887e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.886999353162e+06, best bound 4.886949498941e+06, gap 0.0010%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 139200 rows, 273000 columns and 489320 nonzeros
# Model fingerprint: 0xf3217d06
# Variable types: 262500 continuous, 10500 integer (10500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.93396e+06 (0.09s)
# Loaded MIP start from previous solve with objective 4.93396e+06
#
# Presolve removed 135193 rows and 269069 columns
# Presolve time: 0.05s
# Presolved: 4007 rows, 3931 columns, 13803 nonzeros
# Variable types: 3485 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4933963.61 4933626.62  0.01%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.21 seconds (0.17 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.93396e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.933963607901e+06, best bound 4.933626620730e+06, gap 0.0068%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 146160 rows, 286650 columns and 513786 nonzeros
# Model fingerprint: 0xfa1c8698
# Variable types: 275625 continuous, 11025 integer (11025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.96985e+06 (0.10s)
# Loaded MIP start from previous solve with objective 4.96985e+06
#
# Presolve removed 142139 rows and 282707 columns
# Presolve time: 0.05s
# Presolved: 4021 rows, 3943 columns, 13852 nonzeros
# Variable types: 3497 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4969848.55 4969781.09  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.23 seconds (0.18 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.96985e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.969848545811e+06, best bound 4.969781092166e+06, gap 0.0014%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 153120 rows, 300300 columns and 538252 nonzeros
# Model fingerprint: 0x26374b50
# Variable types: 288750 continuous, 11550 integer (11550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.00221e+06 (0.10s)
# Loaded MIP start from previous solve with objective 5.00221e+06
#
# Presolve removed 149097 rows and 296355 columns
# Presolve time: 0.05s
# Presolved: 4023 rows, 3945 columns, 13860 nonzeros
# Variable types: 3499 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5002208.01 5002149.54  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.23 seconds (0.19 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.00221e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.002208010337e+06, best bound 5.002149538547e+06, gap 0.0012%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 160080 rows, 313950 columns and 562718 nonzeros
# Model fingerprint: 0xf3e3b6c2
# Variable types: 301875 continuous, 12075 integer (12075 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.03255e+06 (0.11s)
# Loaded MIP start from previous solve with objective 5.03255e+06
#
# Presolve removed 156047 rows and 309997 columns
# Presolve time: 0.06s
# Presolved: 4033 rows, 3953 columns, 13892 nonzeros
# Variable types: 3507 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5032548.45 5032413.84  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.03255e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.032548452591e+06, best bound 5.032413843669e+06, gap 0.0027%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 167040 rows, 327600 columns and 587184 nonzeros
# Model fingerprint: 0xc6aa9f51
# Variable types: 315000 continuous, 12600 integer (12600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.05603e+06 (0.11s)
# Loaded MIP start from previous solve with objective 5.05603e+06
#
# Presolve removed 163001 rows and 323641 columns
# Presolve time: 0.06s
# Presolved: 4039 rows, 3959 columns, 13915 nonzeros
# Variable types: 3513 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5056030.65 5055780.68  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.24 seconds (0.20 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.05603e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.056030646458e+06, best bound 5.055780684624e+06, gap 0.0049%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 174000 rows, 341250 columns and 611650 nonzeros
# Model fingerprint: 0xd7e98ae8
# Variable types: 328125 continuous, 13125 integer (13125 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.07705e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.07705e+06
#
# Presolve removed 169954 rows and 337284 columns
# Presolve time: 0.06s
# Presolved: 4046 rows, 3966 columns, 13943 nonzeros
# Variable types: 3520 continuous, 446 integer (446 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      5077050.61 5077050.61  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.25 seconds (0.21 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.07705e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.077050609253e+06, best bound 5.077050609253e+06, gap 0.0000%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 180960 rows, 354900 columns and 636116 nonzeros
# Model fingerprint: 0xc855a8b1
# Variable types: 341250 continuous, 13650 integer (13650 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.09514e+06 (0.11s)
# Loaded MIP start from previous solve with objective 5.09514e+06
#
# Presolve removed 176913 rows and 350933 columns
# Presolve time: 0.06s
# Presolved: 4047 rows, 3967 columns, 13947 nonzeros
# Variable types: 3521 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5095143.06 5094734.89  0.01%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.26 seconds (0.22 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.09514e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.095143060630e+06, best bound 5.094734888714e+06, gap 0.0080%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 187920 rows, 368550 columns and 660582 nonzeros
# Model fingerprint: 0x0bea6c6e
# Variable types: 354375 continuous, 14175 integer (14175 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.10588e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.10588e+06
#
# Presolve removed 183865 rows and 364576 columns
# Presolve time: 0.06s
# Presolved: 4055 rows, 3974 columns, 13975 nonzeros
# Variable types: 3528 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5105882.98 5105783.53  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.28 seconds (0.22 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.10588e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.105882984805e+06, best bound 5.105783529845e+06, gap 0.0019%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 194880 rows, 382200 columns and 685048 nonzeros
# Model fingerprint: 0xce487730
# Variable types: 367500 continuous, 14700 integer (14700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.12196e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.12196e+06
#
# Presolve removed 190812 rows and 378214 columns
# Presolve time: 0.07s
# Presolved: 4068 rows, 3986 columns, 14024 nonzeros
# Variable types: 3540 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5121961.53 5121850.82  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.27 seconds (0.23 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.12196e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.121961532935e+06, best bound 5.121850819419e+06, gap 0.0022%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 201840 rows, 395850 columns and 709514 nonzeros
# Model fingerprint: 0xdf015080
# Variable types: 380625 continuous, 15225 integer (15225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.13408e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.13408e+06
#
# Presolve removed 197762 rows and 391855 columns
# Presolve time: 0.07s
# Presolved: 4078 rows, 3995 columns, 14060 nonzeros
# Variable types: 3549 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5134084.70 5133632.27  0.01%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.28 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.13408e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.134084703082e+06, best bound 5.133632267612e+06, gap 0.0088%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208800 rows, 409500 columns and 733980 nonzeros
# Model fingerprint: 0x8aae58f7
# Variable types: 393750 continuous, 15750 integer (15750 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.14742e+06 (0.12s)
# Loaded MIP start from previous solve with objective 5.14742e+06
#
# Presolve removed 204722 rows and 405505 columns
# Presolve time: 0.07s
# Presolved: 4078 rows, 3995 columns, 14060 nonzeros
# Variable types: 3549 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5147423.74 5146959.57  0.01%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.28 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.14742e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.147423740367e+06, best bound 5.146959570457e+06, gap 0.0090%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 215760 rows, 423150 columns and 758446 nonzeros
# Model fingerprint: 0xebcf3d7a
# Variable types: 406875 continuous, 16275 integer (16275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.15786e+06 (0.13s)
# Loaded MIP start from previous solve with objective 5.15786e+06
#
# Presolve removed 211675 rows and 419150 columns
# Presolve time: 0.08s
# Presolved: 4085 rows, 4000 columns, 14082 nonzeros
# Variable types: 3554 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5157855.43 5157473.03  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.30 seconds (0.25 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.15786e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.157855427267e+06, best bound 5.157473030820e+06, gap 0.0074%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 222720 rows, 436800 columns and 782912 nonzeros
# Model fingerprint: 0xf312b34b
# Variable types: 420000 continuous, 16800 integer (16800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.17076e+06 (0.13s)
# Loaded MIP start from previous solve with objective 5.17076e+06
#
# Presolve removed 218635 rows and 432800 columns
# Presolve time: 0.07s
# Presolved: 4085 rows, 4000 columns, 14082 nonzeros
# Variable types: 3554 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5170757.67 5170537.16  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.31 seconds (0.26 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.17076e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.170757674771e+06, best bound 5.170537164824e+06, gap 0.0043%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 229680 rows, 450450 columns and 807378 nonzeros
# Model fingerprint: 0x905e9147
# Variable types: 433125 continuous, 17325 integer (17325 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.18077e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.18077e+06
#
# Presolve removed 225591 rows and 446446 columns
# Presolve time: 0.08s
# Presolved: 4089 rows, 4004 columns, 14098 nonzeros
# Variable types: 3558 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5180769.21 5180624.41  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.31 seconds (0.27 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.18077e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.180769208549e+06, best bound 5.180624410305e+06, gap 0.0028%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 236640 rows, 464100 columns and 831844 nonzeros
# Model fingerprint: 0x36377f25
# Variable types: 446250 continuous, 17850 integer (17850 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.19123e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.19123e+06
#
# Presolve removed 232548 rows and 460093 columns
# Presolve time: 0.09s
# Presolved: 4092 rows, 4007 columns, 14109 nonzeros
# Variable types: 3561 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5191230.81 5190763.12  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.32 seconds (0.27 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.19123e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.191230812014e+06, best bound 5.190763121490e+06, gap 0.0090%
# Iteration: 35
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 243600 rows, 477750 columns and 856310 nonzeros
# Model fingerprint: 0x905c36b3
# Variable types: 459375 continuous, 18375 integer (18375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.20285e+06 (0.14s)
# Loaded MIP start from previous solve with objective 5.20285e+06
#
# Presolve removed 239508 rows and 473743 columns
# Presolve time: 0.08s
# Presolved: 4092 rows, 4007 columns, 14109 nonzeros
# Variable types: 3561 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5202850.11 5202382.11  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.32 seconds (0.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.20285e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.202850110977e+06, best bound 5.202382108289e+06, gap 0.0090%
# Iteration: 36
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 250560 rows, 491400 columns and 880776 nonzeros
# Model fingerprint: 0xe7fbf70e
# Variable types: 472500 continuous, 18900 integer (18900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+04]
#   Objective range  [2e+01, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 5.21146e+06 (0.15s)
# Loaded MIP start from previous solve with objective 5.21146e+06
#
# Presolve removed 246461 rows and 487387 columns
# Presolve time: 0.08s
# Presolved: 4099 rows, 4013 columns, 14134 nonzeros
# Variable types: 3567 continuous, 446 integer (446 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      5211460.11 5211347.59  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.34 seconds (0.29 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 5.21146e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.211460110143e+06, best bound 5.211347593347e+06, gap 0.0022%

# %%
sheet_name = sheet_list[4]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-100-24 (1)
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34800 rows, 65650 columns and 122360 nonzeros
# Model fingerprint: 0x437ffeed
# Variable types: 63125 continuous, 2525 integer (2525 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 7.120177e+07
# Presolve removed 34655 rows and 65498 columns
# Presolve time: 0.11s
# Presolved: 145 rows, 152 columns, 396 nonzeros
# Found heuristic solution: objective 1.943796e+07
# Variable types: 83 continuous, 69 integer (69 binary)
#
# Root relaxation: objective 1.938694e+07, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.938694e+07 1.9387e+07  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.13 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 1.93869e+07 1.9438e+07 7.12018e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.938693800000e+07, best bound 1.938693800000e+07, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69600 rows, 131300 columns and 244720 nonzeros
# Model fingerprint: 0x1add38a3
# Variable types: 126250 continuous, 5050 integer (5050 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.96623e+07 (0.11s)
# Loaded MIP start from previous solve with objective 1.96623e+07
#
# Presolve removed 58939 rows and 120868 columns
# Presolve time: 0.04s
# Presolved: 10661 rows, 10432 columns, 34825 nonzeros
# Variable types: 9090 continuous, 1342 integer (1339 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.26 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.96623e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.966228236703e+07, best bound 1.966050571978e+07, gap 0.0090%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 104400 rows, 196950 columns and 367080 nonzeros
# Model fingerprint: 0x7c12bb03
# Variable types: 189375 continuous, 7575 integer (7575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.9927e+07 (0.15s)
# Loaded MIP start from previous solve with objective 1.9927e+07
#
# Presolve removed 85170 rows and 177958 columns
# Presolve time: 0.05s
# Presolved: 19230 rows, 18992 columns, 66303 nonzeros
# Variable types: 16732 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.33 seconds (0.31 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.9927e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.992700639341e+07, best bound 1.992523017850e+07, gap 0.0089%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 139200 rows, 262600 columns and 489440 nonzeros
# Model fingerprint: 0xf4dc8e03
# Variable types: 252500 continuous, 10100 integer (10100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.01681e+07 (0.18s)
# Loaded MIP start from previous solve with objective 2.01681e+07
#
# Presolve removed 119867 rows and 243531 columns
# Presolve time: 0.06s
# Presolved: 19333 rows, 19069 columns, 66612 nonzeros
# Variable types: 16809 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.40 seconds (0.35 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.01681e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.016811016249e+07, best bound 2.016633437322e+07, gap 0.0088%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 174000 rows, 328250 columns and 611800 nonzeros
# Model fingerprint: 0xa856b914
# Variable types: 315625 continuous, 12625 integer (12625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.04026e+07 (0.19s)
# Loaded MIP start from previous solve with objective 2.04026e+07
#
# Presolve removed 154643 rows and 309161 columns
# Presolve time: 0.07s
# Presolved: 19357 rows, 19089 columns, 66695 nonzeros
# Variable types: 16829 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.43 seconds (0.38 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.04026e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.040263768834e+07, best bound 2.040086240251e+07, gap 0.0087%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208800 rows, 393900 columns and 734160 nonzeros
# Model fingerprint: 0xce662447
# Variable types: 378750 continuous, 15150 integer (15150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.06107e+07 (0.22s)
# Loaded MIP start from previous solve with objective 2.06107e+07
#
# Presolve removed 189368 rows and 374744 columns
# Presolve time: 0.08s
# Presolved: 19432 rows, 19156 columns, 66957 nonzeros
# Variable types: 16896 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.0611e+07 2.0609e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.48 seconds (0.42 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.06107e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.061071058187e+07, best bound 2.060878017014e+07, gap 0.0094%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 243600 rows, 459550 columns and 856520 nonzeros
# Model fingerprint: 0x71b678b7
# Variable types: 441875 continuous, 17675 integer (17675 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.08203e+07 (0.23s)
# Loaded MIP start from previous solve with objective 2.08203e+07
#
# Presolve removed 224125 rows and 440358 columns
# Presolve time: 0.09s
# Presolved: 19475 rows, 19192 columns, 67099 nonzeros
# Variable types: 16932 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.0820e+07 2.0818e+07  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.51 seconds (0.46 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.08203e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.082033534616e+07, best bound 2.081840191549e+07, gap 0.0093%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 278400 rows, 525200 columns and 978880 nonzeros
# Model fingerprint: 0xebfd3067
# Variable types: 505000 continuous, 20200 integer (20200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.10267e+07 (0.25s)
# Loaded MIP start from previous solve with objective 2.10267e+07
#
# Presolve removed 258857 rows and 505951 columns
# Presolve time: 0.12s
# Presolved: 19543 rows, 19249 columns, 67329 nonzeros
# Variable types: 16989 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1027e+07 2.1025e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.58 seconds (0.50 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.10267e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.102666283363e+07, best bound 2.102464652541e+07, gap 0.0096%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 313200 rows, 590850 columns and 1101240 nonzeros
# Model fingerprint: 0x0135d940
# Variable types: 568125 continuous, 22725 integer (22725 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.12315e+07 (0.27s)
# Loaded MIP start from previous solve with objective 2.12315e+07
#
# Presolve removed 293623 rows and 571573 columns
# Presolve time: 0.13s
# Presolved: 19577 rows, 19277 columns, 67441 nonzeros
# Variable types: 17017 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1232e+07 2.1230e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.60 seconds (0.54 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.12315e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.123150870933e+07, best bound 2.122966406791e+07, gap 0.0087%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 348000 rows, 656500 columns and 1223600 nonzeros
# Model fingerprint: 0x865827da
# Variable types: 631250 continuous, 25250 integer (25250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.14329e+07 (0.29s)
# Loaded MIP start from previous solve with objective 2.14329e+07
#
# Presolve removed 328355 rows and 637165 columns
# Presolve time: 0.13s
# Presolved: 19645 rows, 19335 columns, 67675 nonzeros
# Variable types: 17075 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1433e+07 2.1431e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.63 seconds (0.58 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.14329e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.143290320163e+07, best bound 2.143086785154e+07, gap 0.0095%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 382800 rows, 722150 columns and 1345960 nonzeros
# Model fingerprint: 0x5fec766d
# Variable types: 694375 continuous, 27775 integer (27775 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.16345e+07 (0.32s)
# Loaded MIP start from previous solve with objective 2.16345e+07
#
# Presolve removed 363099 rows and 702765 columns
# Presolve time: 0.14s
# Presolved: 19701 rows, 19385 columns, 67871 nonzeros
# Variable types: 17125 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1634e+07 2.1633e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.70 seconds (0.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.16345e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.163447002635e+07, best bound 2.163267228458e+07, gap 0.0083%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 417600 rows, 787800 columns and 1468320 nonzeros
# Model fingerprint: 0x836216d2
# Variable types: 757500 continuous, 30300 integer (30300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.18238e+07 (0.31s)
# Loaded MIP start from previous solve with objective 2.18238e+07
# Presolve removed 397832 rows and 768362 columns
# Presolve time: 0.16s
# Presolved: 19768 rows, 19438 columns, 68087 nonzeros
# Variable types: 17178 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1824e+07 2.1822e+07  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.70 seconds (0.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.18238e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.182382669141e+07, best bound 2.182196163618e+07, gap 0.0085%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 452400 rows, 853450 columns and 1590680 nonzeros
# Model fingerprint: 0x39db3d72
# Variable types: 820625 continuous, 32825 integer (32825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.20335e+07 (0.34s)
# Loaded MIP start from previous solve with objective 2.20335e+07
#
# Presolve removed 432560 rows and 833953 columns
# Presolve time: 0.16s
# Presolved: 19840 rows, 19497 columns, 68333 nonzeros
# Variable types: 17237 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2033e+07 2.2031e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.75 seconds (0.70 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.20335e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.203347758489e+07, best bound 2.203143014128e+07, gap 0.0093%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 487200 rows, 919100 columns and 1713040 nonzeros
# Model fingerprint: 0x9148e158
# Variable types: 883750 continuous, 35350 integer (35350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.22357e+07 (0.36s)
# Loaded MIP start from previous solve with objective 2.22357e+07
#
# Presolve removed 467339 rows and 899583 columns
# Presolve time: 0.19s
# Presolved: 19861 rows, 19517 columns, 68411 nonzeros
# Variable types: 17257 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2236e+07 2.2234e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.80 seconds (0.74 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.22357e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.223569125719e+07, best bound 2.223362304229e+07, gap 0.0093%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 522000 rows, 984750 columns and 1835400 nonzeros
# Model fingerprint: 0x7d82e670
# Variable types: 946875 continuous, 37875 integer (37875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.2439e+07 (0.38s)
# Loaded MIP start from previous solve with objective 2.2439e+07
#
# Presolve removed 502116 rows and 965213 columns
# Presolve time: 0.21s
# Presolved: 19884 rows, 19537 columns, 68492 nonzeros
# Variable types: 17277 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2439e+07 2.2437e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.86 seconds (0.78 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.2439e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.243900144867e+07, best bound 2.243698342172e+07, gap 0.0090%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 556800 rows, 1050400 columns and 1957760 nonzeros
# Model fingerprint: 0x780f2ecc
# Variable types: 1010000 continuous, 40400 integer (40400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.26419e+07 (0.41s)
# Loaded MIP start from previous solve with objective 2.26419e+07
#
# Presolve removed 536880 rows and 1030832 columns
# Presolve time: 0.20s
# Presolved: 19920 rows, 19568 columns, 68620 nonzeros
# Variable types: 17308 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.92 seconds (0.82 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.26419e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.264190743075e+07, best bound 2.263997476498e+07, gap 0.0085%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 591600 rows, 1116050 columns and 2080120 nonzeros
# Model fingerprint: 0x1e349ed2
# Variable types: 1073125 continuous, 42925 integer (42925 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.28433e+07 (0.39s)
# Loaded MIP start from previous solve with objective 2.28433e+07
#
# Presolve removed 571655 rows and 1096460 columns
# Presolve time: 0.21s
# Presolved: 19945 rows, 19590 columns, 68711 nonzeros
# Variable types: 17330 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.89 seconds (0.86 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.28433e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.284329468582e+07, best bound 2.284136197064e+07, gap 0.0085%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 626400 rows, 1181700 columns and 2202480 nonzeros
# Model fingerprint: 0x0bc4a4e9
# Variable types: 1136250 continuous, 45450 integer (45450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.30413e+07 (0.51s)
# Loaded MIP start from previous solve with objective 2.30413e+07
#
# Presolve removed 606413 rows and 1162068 columns
# Presolve time: 0.22s
# Presolved: 19987 rows, 19632 columns, 68879 nonzeros
# Variable types: 17372 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.3041e+07 2.3039e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 1.03 seconds (0.90 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.30413e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.304130892678e+07, best bound 2.303916840830e+07, gap 0.0093%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 661200 rows, 1247350 columns and 2324840 nonzeros
# Model fingerprint: 0xd06dfd48
# Variable types: 1199375 continuous, 47975 integer (47975 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.32159e+07 (0.44s)
# Loaded MIP start from previous solve with objective 2.32159e+07
#
# Presolve removed 641176 rows and 1227690 columns
# Presolve time: 0.24s
# Presolved: 20024 rows, 19660 columns, 68996 nonzeros
# Variable types: 17400 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.3216e+07 2.3214e+07  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.98 seconds (0.94 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.32159e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.321592357374e+07, best bound 2.321383662994e+07, gap 0.0090%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 696000 rows, 1313000 columns and 2447200 nonzeros
# Model fingerprint: 0x140a0072
# Variable types: 1262500 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.33579e+07 (0.45s)
# Loaded MIP start from previous solve with objective 2.33579e+07
#
# Presolve removed 675931 rows and 1293297 columns
# Presolve time: 0.25s
# Presolved: 20069 rows, 19703 columns, 69169 nonzeros
# Variable types: 17443 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.01 seconds (0.98 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.33579e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.335791844110e+07, best bound 2.335586719588e+07, gap 0.0088%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 730800 rows, 1378650 columns and 2569560 nonzeros
# Model fingerprint: 0x1f0ddbd4
# Variable types: 1325625 continuous, 53025 integer (53025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.34971e+07 (0.46s)
# Loaded MIP start from previous solve with objective 2.34971e+07
#
# Presolve removed 710682 rows and 1358902 columns
# Presolve time: 0.26s
# Presolved: 20118 rows, 19748 columns, 69351 nonzeros
# Variable types: 17488 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.03 seconds (1.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.34971e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.349714200045e+07, best bound 2.349482716471e+07, gap 0.0099%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 765600 rows, 1444300 columns and 2691920 nonzeros
# Model fingerprint: 0x634f723a
# Variable types: 1388750 continuous, 55550 integer (55550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.36285e+07 (0.48s)
# Loaded MIP start from previous solve with objective 2.36285e+07
#
# Presolve removed 745425 rows and 1424502 columns
# Presolve time: 0.28s
# Presolved: 20175 rows, 19798 columns, 69550 nonzeros
# Variable types: 17538 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.10 seconds (1.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.36285e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.362852408706e+07, best bound 2.362620939427e+07, gap 0.0098%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 800400 rows, 1509950 columns and 2814280 nonzeros
# Model fingerprint: 0x310f2068
# Variable types: 1451875 continuous, 58075 integer (58075 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.3759e+07 (0.49s)
# Loaded MIP start from previous solve with objective 2.3759e+07
#
# Presolve removed 780199 rows and 1490129 columns
# Presolve time: 0.31s
# Presolved: 20201 rows, 19821 columns, 69644 nonzeros
# Variable types: 17561 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.14 seconds (1.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.3759e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.375896955168e+07, best bound 2.375665489741e+07, gap 0.0097%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 835200 rows, 1575600 columns and 2936640 nonzeros
# Model fingerprint: 0xe52da3a7
# Variable types: 1515000 continuous, 60600 integer (60600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.38625e+07 (0.55s)
# Loaded MIP start from previous solve with objective 2.38625e+07
#
# Presolve removed 814970 rows and 1555755 columns
# Presolve time: 0.30s
# Presolved: 20230 rows, 19845 columns, 69745 nonzeros
# Variable types: 17585 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.22 seconds (1.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.38625e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.386247810730e+07, best bound 2.386016359546e+07, gap 0.0097%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 870000 rows, 1641250 columns and 3059000 nonzeros
# Model fingerprint: 0x8927f564
# Variable types: 1578125 continuous, 63125 integer (63125 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.39665e+07 (0.54s)
# Loaded MIP start from previous solve with objective 2.39665e+07
#
# Presolve removed 849755 rows and 1621390 columns
# Presolve time: 0.31s
# Presolved: 20245 rows, 19860 columns, 69805 nonzeros
# Variable types: 17600 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.20 seconds (1.19 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.39665e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.396650806110e+07, best bound 2.396419354684e+07, gap 0.0097%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 904800 rows, 1706900 columns and 3181360 nonzeros
# Model fingerprint: 0xe3c35761
# Variable types: 1641250 continuous, 65650 integer (65650 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.40457e+07 (0.61s)
# Loaded MIP start from previous solve with objective 2.40457e+07
#
# Presolve removed 884537 rows and 1687023 columns
# Presolve time: 0.32s
# Presolved: 20263 rows, 19877 columns, 69874 nonzeros
# Variable types: 17617 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.31 seconds (1.23 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.40457e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.404573198618e+07, best bound 2.404341740708e+07, gap 0.0096%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 939600 rows, 1772550 columns and 3303720 nonzeros
# Model fingerprint: 0x6ae4723d
# Variable types: 1704375 continuous, 68175 integer (68175 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.41318e+07 (0.57s)
# Loaded MIP start from previous solve with objective 2.41318e+07
#
# Presolve removed 919313 rows and 1752650 columns
# Presolve time: 0.33s
# Presolved: 20287 rows, 19900 columns, 69963 nonzeros
# Variable types: 17640 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.27 seconds (1.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.41318e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.413176800929e+07, best bound 2.412945349138e+07, gap 0.0096%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 974400 rows, 1838200 columns and 3426080 nonzeros
# Model fingerprint: 0xa21606ce
# Variable types: 1767500 continuous, 70700 integer (70700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.41989e+07 (0.63s)
# Loaded MIP start from previous solve with objective 2.41989e+07
#
# Presolve removed 954081 rows and 1818274 columns
# Presolve time: 0.37s
# Presolved: 20319 rows, 19926 columns, 70073 nonzeros
# Variable types: 17666 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.41 seconds (1.32 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.41989e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.419893648309e+07, best bound 2.419662190630e+07, gap 0.0096%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1009200 rows, 1903850 columns and 3548440 nonzeros
# Model fingerprint: 0xdbb2d834
# Variable types: 1830625 continuous, 73225 integer (73225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.42594e+07 (0.65s)
# Loaded MIP start from previous solve with objective 2.42594e+07
#
# Presolve removed 988868 rows and 1883914 columns
# Presolve time: 0.38s
# Presolved: 20332 rows, 19936 columns, 70116 nonzeros
# Variable types: 17676 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.44 seconds (1.36 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.42594e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.425935796770e+07, best bound 2.425704344537e+07, gap 0.0095%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1044000 rows, 1969500 columns and 3670800 nonzeros
# Model fingerprint: 0x4b3841ee
# Variable types: 1893750 continuous, 75750 integer (75750 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.43197e+07 (0.62s)
# Loaded MIP start from previous solve with objective 2.43197e+07
#
# Presolve removed 1023642 rows and 1949544 columns
# Presolve time: 0.39s
# Presolved: 20358 rows, 19956 columns, 70201 nonzeros
# Variable types: 17696 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.42 seconds (1.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.43197e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.431970322872e+07, best bound 2.431738862386e+07, gap 0.0095%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1078800 rows, 2035150 columns and 3793160 nonzeros
# Model fingerprint: 0x500f7ef1
# Variable types: 1956875 continuous, 78275 integer (78275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.43723e+07 (0.69s)
# Loaded MIP start from previous solve with objective 2.43723e+07
#
# Presolve removed 1058401 rows and 2015159 columns
# Presolve time: 0.40s
# Presolved: 20399 rows, 19991 columns, 70344 nonzeros
# Variable types: 17731 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.50 seconds (1.44 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.43723e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.437226237852e+07, best bound 2.436994770924e+07, gap 0.0095%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1113600 rows, 2100800 columns and 3915520 nonzeros
# Model fingerprint: 0x44ff5a64
# Variable types: 2020000 continuous, 80800 integer (80800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.44254e+07 (0.65s)
# Loaded MIP start from previous solve with objective 2.44254e+07
#
# Presolve removed 1093187 rows and 2080797 columns
# Presolve time: 0.41s
# Presolved: 20413 rows, 20003 columns, 70392 nonzeros
# Variable types: 17743 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.52 seconds (1.48 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.44254e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.442535798217e+07, best bound 2.442314414473e+07, gap 0.0091%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1148400 rows, 2166450 columns and 4037880 nonzeros
# Model fingerprint: 0xf7365fad
# Variable types: 2083125 continuous, 83325 integer (83325 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.44804e+07 (0.72s)
# Loaded MIP start from previous solve with objective 2.44804e+07
#
# Presolve removed 1127969 rows and 2146432 columns
# Presolve time: 0.43s
# Presolved: 20431 rows, 20018 columns, 70455 nonzeros
# Variable types: 17758 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.4480e+07 2.4478e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.60 seconds (1.53 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.44804e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.448039654125e+07, best bound 2.447802738622e+07, gap 0.0097%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1183200 rows, 2232100 columns and 4160240 nonzeros
# Model fingerprint: 0xfa45f6d6
# Variable types: 2146250 continuous, 85850 integer (85850 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.45282e+07 (0.68s)
# Loaded MIP start from previous solve with objective 2.45282e+07
#
# Presolve removed 1162745 rows and 2212059 columns
# Presolve time: 0.43s
# Presolved: 20455 rows, 20041 columns, 70545 nonzeros
# Variable types: 17781 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.56 seconds (1.57 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.45282e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.452824303268e+07, best bound 2.452586072715e+07, gap 0.0097%

# %%
sheet_name = sheet_list[5]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-100-24 (2)
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 34800 rows, 65650 columns and 122360 nonzeros
# Model fingerprint: 0x437ffeed
# Variable types: 63125 continuous, 2525 integer (2525 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 7.120177e+07
# Presolve removed 34655 rows and 65498 columns
# Presolve time: 0.11s
# Presolved: 145 rows, 152 columns, 396 nonzeros
# Found heuristic solution: objective 1.943796e+07
# Variable types: 83 continuous, 69 integer (69 binary)
#
# Root relaxation: objective 1.938694e+07, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.938694e+07 1.9387e+07  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.13 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 1.93869e+07 1.9438e+07 7.12018e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.938693800000e+07, best bound 1.938693800000e+07, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69600 rows, 131300 columns and 244720 nonzeros
# Model fingerprint: 0x1add38a3
# Variable types: 126250 continuous, 5050 integer (5050 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.96623e+07 (0.12s)
# Loaded MIP start from previous solve with objective 1.96623e+07
#
# Presolve removed 58939 rows and 120868 columns
# Presolve time: 0.04s
# Presolved: 10661 rows, 10432 columns, 34825 nonzeros
# Variable types: 9090 continuous, 1342 integer (1339 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.27 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.96623e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.966228236703e+07, best bound 1.966050571978e+07, gap 0.0090%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 104400 rows, 196950 columns and 367080 nonzeros
# Model fingerprint: 0x7c12bb03
# Variable types: 189375 continuous, 7575 integer (7575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 1.9927e+07 (0.16s)
# Loaded MIP start from previous solve with objective 1.9927e+07
#
# Presolve removed 85170 rows and 177958 columns
# Presolve time: 0.04s
# Presolved: 19230 rows, 18992 columns, 66303 nonzeros
# Variable types: 16732 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.33 seconds (0.31 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 1.9927e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.992700639341e+07, best bound 1.992523017850e+07, gap 0.0089%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 139200 rows, 262600 columns and 489440 nonzeros
# Model fingerprint: 0xf4dc8e03
# Variable types: 252500 continuous, 10100 integer (10100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.01681e+07 (0.17s)
# Loaded MIP start from previous solve with objective 2.01681e+07
#
# Presolve removed 119867 rows and 243531 columns
# Presolve time: 0.05s
# Presolved: 19333 rows, 19069 columns, 66612 nonzeros
# Variable types: 16809 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.38 seconds (0.35 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.01681e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.016811016249e+07, best bound 2.016633437322e+07, gap 0.0088%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 174000 rows, 328250 columns and 611800 nonzeros
# Model fingerprint: 0xa856b914
# Variable types: 315625 continuous, 12625 integer (12625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.04026e+07 (0.19s)
# Loaded MIP start from previous solve with objective 2.04026e+07
#
# Presolve removed 154643 rows and 309161 columns
# Presolve time: 0.07s
# Presolved: 19357 rows, 19089 columns, 66695 nonzeros
# Variable types: 16829 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.43 seconds (0.38 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.04026e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.040263768834e+07, best bound 2.040086240251e+07, gap 0.0087%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208800 rows, 393900 columns and 734160 nonzeros
# Model fingerprint: 0xce662447
# Variable types: 378750 continuous, 15150 integer (15150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.06107e+07 (0.22s)
# Loaded MIP start from previous solve with objective 2.06107e+07
#
# Presolve removed 189368 rows and 374744 columns
# Presolve time: 0.08s
# Presolved: 19432 rows, 19156 columns, 66957 nonzeros
# Variable types: 16896 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.0611e+07 2.0609e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.47 seconds (0.42 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.06107e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.061071058187e+07, best bound 2.060878017014e+07, gap 0.0094%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 243600 rows, 459550 columns and 856520 nonzeros
# Model fingerprint: 0x71b678b7
# Variable types: 441875 continuous, 17675 integer (17675 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.08203e+07 (0.24s)
# Loaded MIP start from previous solve with objective 2.08203e+07
#
# Presolve removed 224125 rows and 440358 columns
# Presolve time: 0.10s
# Presolved: 19475 rows, 19192 columns, 67099 nonzeros
# Variable types: 16932 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.0820e+07 2.0818e+07  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.53 seconds (0.46 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.08203e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.082033534616e+07, best bound 2.081840191549e+07, gap 0.0093%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 278400 rows, 525200 columns and 978880 nonzeros
# Model fingerprint: 0xebfd3067
# Variable types: 505000 continuous, 20200 integer (20200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.10267e+07 (0.24s)
# Loaded MIP start from previous solve with objective 2.10267e+07
#
# Presolve removed 258857 rows and 505951 columns
# Presolve time: 0.10s
# Presolved: 19543 rows, 19249 columns, 67329 nonzeros
# Variable types: 16989 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1027e+07 2.1025e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.54 seconds (0.50 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.10267e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.102666283363e+07, best bound 2.102464652541e+07, gap 0.0096%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 313200 rows, 590850 columns and 1101240 nonzeros
# Model fingerprint: 0x0135d940
# Variable types: 568125 continuous, 22725 integer (22725 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.12315e+07 (0.27s)
# Loaded MIP start from previous solve with objective 2.12315e+07
#
# Presolve removed 293623 rows and 571573 columns
# Presolve time: 0.12s
# Presolved: 19577 rows, 19277 columns, 67441 nonzeros
# Variable types: 17017 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1232e+07 2.1230e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.61 seconds (0.54 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.12315e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.123150870933e+07, best bound 2.122966406791e+07, gap 0.0087%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 348000 rows, 656500 columns and 1223600 nonzeros
# Model fingerprint: 0x865827da
# Variable types: 631250 continuous, 25250 integer (25250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.14329e+07 (0.28s)
# Loaded MIP start from previous solve with objective 2.14329e+07
#
# Presolve removed 328355 rows and 637165 columns
# Presolve time: 0.13s
# Presolved: 19645 rows, 19335 columns, 67675 nonzeros
# Variable types: 17075 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1433e+07 2.1431e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.62 seconds (0.58 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.14329e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.143290320163e+07, best bound 2.143086785154e+07, gap 0.0095%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 382800 rows, 722150 columns and 1345960 nonzeros
# Model fingerprint: 0x5fec766d
# Variable types: 694375 continuous, 27775 integer (27775 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.16345e+07 (0.29s)
# Loaded MIP start from previous solve with objective 2.16345e+07
#
# Presolve removed 363099 rows and 702765 columns
# Presolve time: 0.14s
# Presolved: 19701 rows, 19385 columns, 67871 nonzeros
# Variable types: 17125 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1634e+07 2.1633e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.65 seconds (0.62 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.16345e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.163447002635e+07, best bound 2.163267228458e+07, gap 0.0083%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 417600 rows, 787800 columns and 1468320 nonzeros
# Model fingerprint: 0x836216d2
# Variable types: 757500 continuous, 30300 integer (30300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.18238e+07 (0.32s)
# Loaded MIP start from previous solve with objective 2.18238e+07
# Presolve removed 397832 rows and 768362 columns
# Presolve time: 0.15s
# Presolved: 19768 rows, 19438 columns, 68087 nonzeros
# Variable types: 17178 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.1824e+07 2.1822e+07  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.69 seconds (0.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.18238e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.182382669141e+07, best bound 2.182196163618e+07, gap 0.0085%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 452400 rows, 853450 columns and 1590680 nonzeros
# Model fingerprint: 0x39db3d72
# Variable types: 820625 continuous, 32825 integer (32825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.20335e+07 (0.35s)
# Loaded MIP start from previous solve with objective 2.20335e+07
#
# Presolve removed 432560 rows and 833953 columns
# Presolve time: 0.17s
# Presolved: 19840 rows, 19497 columns, 68333 nonzeros
# Variable types: 17237 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2033e+07 2.2031e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.77 seconds (0.70 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.20335e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.203347758489e+07, best bound 2.203143014128e+07, gap 0.0093%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 487200 rows, 919100 columns and 1713040 nonzeros
# Model fingerprint: 0x9148e158
# Variable types: 883750 continuous, 35350 integer (35350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.22357e+07 (0.34s)
# Loaded MIP start from previous solve with objective 2.22357e+07
#
# Presolve removed 467339 rows and 899583 columns
# Presolve time: 0.18s
# Presolved: 19861 rows, 19517 columns, 68411 nonzeros
# Variable types: 17257 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2236e+07 2.2234e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.77 seconds (0.74 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.22357e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.223569125719e+07, best bound 2.223362304229e+07, gap 0.0093%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 522000 rows, 984750 columns and 1835400 nonzeros
# Model fingerprint: 0x7d82e670
# Variable types: 946875 continuous, 37875 integer (37875 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.2439e+07 (0.37s)
# Loaded MIP start from previous solve with objective 2.2439e+07
#
# Presolve removed 502116 rows and 965213 columns
# Presolve time: 0.20s
# Presolved: 19884 rows, 19537 columns, 68492 nonzeros
# Variable types: 17277 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.2439e+07 2.2437e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.84 seconds (0.78 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.2439e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.243900144867e+07, best bound 2.243698342172e+07, gap 0.0090%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 556800 rows, 1050400 columns and 1957760 nonzeros
# Model fingerprint: 0x780f2ecc
# Variable types: 1010000 continuous, 40400 integer (40400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.26419e+07 (0.39s)
# Loaded MIP start from previous solve with objective 2.26419e+07
#
# Presolve removed 536880 rows and 1030832 columns
# Presolve time: 0.21s
# Presolved: 19920 rows, 19568 columns, 68620 nonzeros
# Variable types: 17308 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.88 seconds (0.82 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.26419e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.264190743075e+07, best bound 2.263997476498e+07, gap 0.0085%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 591600 rows, 1116050 columns and 2080120 nonzeros
# Model fingerprint: 0x1e349ed2
# Variable types: 1073125 continuous, 42925 integer (42925 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.28433e+07 (0.40s)
# Loaded MIP start from previous solve with objective 2.28433e+07
#
# Presolve removed 571655 rows and 1096460 columns
# Presolve time: 0.21s
# Presolved: 19945 rows, 19590 columns, 68711 nonzeros
# Variable types: 17330 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.90 seconds (0.86 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.28433e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.284329468582e+07, best bound 2.284136197064e+07, gap 0.0085%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 626400 rows, 1181700 columns and 2202480 nonzeros
# Model fingerprint: 0x0bc4a4e9
# Variable types: 1136250 continuous, 45450 integer (45450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.30413e+07 (0.41s)
# Loaded MIP start from previous solve with objective 2.30413e+07
#
# Presolve removed 606413 rows and 1162068 columns
# Presolve time: 0.24s
# Presolved: 19987 rows, 19632 columns, 68879 nonzeros
# Variable types: 17372 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.3041e+07 2.3039e+07  0.01%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.95 seconds (0.90 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.30413e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.304130892678e+07, best bound 2.303916840830e+07, gap 0.0093%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 661200 rows, 1247350 columns and 2324840 nonzeros
# Model fingerprint: 0xd06dfd48
# Variable types: 1199375 continuous, 47975 integer (47975 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.32159e+07 (0.42s)
# Loaded MIP start from previous solve with objective 2.32159e+07
#
# Presolve removed 641176 rows and 1227690 columns
# Presolve time: 0.25s
# Presolved: 20024 rows, 19660 columns, 68996 nonzeros
# Variable types: 17400 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.3216e+07 2.3214e+07  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.96 seconds (0.94 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.32159e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.321592357374e+07, best bound 2.321383662994e+07, gap 0.0090%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 696000 rows, 1313000 columns and 2447200 nonzeros
# Model fingerprint: 0x140a0072
# Variable types: 1262500 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.33579e+07 (0.45s)
# Loaded MIP start from previous solve with objective 2.33579e+07
#
# Presolve removed 675931 rows and 1293297 columns
# Presolve time: 0.25s
# Presolved: 20069 rows, 19703 columns, 69169 nonzeros
# Variable types: 17443 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.01 seconds (0.98 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.33579e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.335791844110e+07, best bound 2.335586719588e+07, gap 0.0088%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 730800 rows, 1378650 columns and 2569560 nonzeros
# Model fingerprint: 0x1f0ddbd4
# Variable types: 1325625 continuous, 53025 integer (53025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.34971e+07 (0.51s)
# Loaded MIP start from previous solve with objective 2.34971e+07
#
# Presolve removed 710682 rows and 1358902 columns
# Presolve time: 0.29s
# Presolved: 20118 rows, 19748 columns, 69351 nonzeros
# Variable types: 17488 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.16 seconds (1.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.34971e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.349714200045e+07, best bound 2.349482716471e+07, gap 0.0099%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 765600 rows, 1444300 columns and 2691920 nonzeros
# Model fingerprint: 0x634f723a
# Variable types: 1388750 continuous, 55550 integer (55550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.36285e+07 (0.47s)
# Loaded MIP start from previous solve with objective 2.36285e+07
#
# Presolve removed 745425 rows and 1424502 columns
# Presolve time: 0.30s
# Presolved: 20175 rows, 19798 columns, 69550 nonzeros
# Variable types: 17538 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.10 seconds (1.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.36285e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.362852408706e+07, best bound 2.362620939427e+07, gap 0.0098%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 800400 rows, 1509950 columns and 2814280 nonzeros
# Model fingerprint: 0x310f2068
# Variable types: 1451875 continuous, 58075 integer (58075 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.3759e+07 (0.51s)
# Loaded MIP start from previous solve with objective 2.3759e+07
#
# Presolve removed 780199 rows and 1490129 columns
# Presolve time: 0.33s
# Presolved: 20201 rows, 19821 columns, 69644 nonzeros
# Variable types: 17561 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.22 seconds (1.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.3759e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.375896955168e+07, best bound 2.375665489741e+07, gap 0.0097%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 835200 rows, 1575600 columns and 2936640 nonzeros
# Model fingerprint: 0xe52da3a7
# Variable types: 1515000 continuous, 60600 integer (60600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.38625e+07 (0.63s)
# Loaded MIP start from previous solve with objective 2.38625e+07
#
# Presolve removed 814970 rows and 1555755 columns
# Presolve time: 0.35s
# Presolved: 20230 rows, 19845 columns, 69745 nonzeros
# Variable types: 17585 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.39 seconds (1.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.38625e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.386247810730e+07, best bound 2.386016359546e+07, gap 0.0097%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 870000 rows, 1641250 columns and 3059000 nonzeros
# Model fingerprint: 0x8927f564
# Variable types: 1578125 continuous, 63125 integer (63125 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.39665e+07 (0.58s)
# Loaded MIP start from previous solve with objective 2.39665e+07
#
# Presolve removed 849755 rows and 1621390 columns
# Presolve time: 0.34s
# Presolved: 20245 rows, 19860 columns, 69805 nonzeros
# Variable types: 17600 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.33 seconds (1.19 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.39665e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.396650806110e+07, best bound 2.396419354684e+07, gap 0.0097%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 904800 rows, 1706900 columns and 3181360 nonzeros
# Model fingerprint: 0xe3c35761
# Variable types: 1641250 continuous, 65650 integer (65650 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.40457e+07 (0.63s)
# Loaded MIP start from previous solve with objective 2.40457e+07
#
# Presolve removed 884537 rows and 1687023 columns
# Presolve time: 0.37s
# Presolved: 20263 rows, 19877 columns, 69874 nonzeros
# Variable types: 17617 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.39 seconds (1.23 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.40457e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.404573198618e+07, best bound 2.404341740708e+07, gap 0.0096%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 939600 rows, 1772550 columns and 3303720 nonzeros
# Model fingerprint: 0x6ae4723d
# Variable types: 1704375 continuous, 68175 integer (68175 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.41318e+07 (0.62s)
# Loaded MIP start from previous solve with objective 2.41318e+07
#
# Presolve removed 919313 rows and 1752650 columns
# Presolve time: 0.37s
# Presolved: 20287 rows, 19900 columns, 69963 nonzeros
# Variable types: 17640 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.39 seconds (1.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.41318e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.413176800929e+07, best bound 2.412945349138e+07, gap 0.0096%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 974400 rows, 1838200 columns and 3426080 nonzeros
# Model fingerprint: 0xa21606ce
# Variable types: 1767500 continuous, 70700 integer (70700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.41989e+07 (0.58s)
# Loaded MIP start from previous solve with objective 2.41989e+07
#
# Presolve removed 954081 rows and 1818274 columns
# Presolve time: 0.36s
# Presolved: 20319 rows, 19926 columns, 70073 nonzeros
# Variable types: 17666 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.31 seconds (1.32 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.41989e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.419893648309e+07, best bound 2.419662190630e+07, gap 0.0096%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1009200 rows, 1903850 columns and 3548440 nonzeros
# Model fingerprint: 0xdbb2d834
# Variable types: 1830625 continuous, 73225 integer (73225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.42594e+07 (0.65s)
# Loaded MIP start from previous solve with objective 2.42594e+07
#
# Presolve removed 988868 rows and 1883914 columns
# Presolve time: 0.40s
# Presolved: 20332 rows, 19936 columns, 70116 nonzeros
# Variable types: 17676 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.47 seconds (1.36 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.42594e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.425935796770e+07, best bound 2.425704344537e+07, gap 0.0095%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1044000 rows, 1969500 columns and 3670800 nonzeros
# Model fingerprint: 0x4b3841ee
# Variable types: 1893750 continuous, 75750 integer (75750 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.43197e+07 (0.63s)
# Loaded MIP start from previous solve with objective 2.43197e+07
#
# Presolve removed 1023642 rows and 1949544 columns
# Presolve time: 0.39s
# Presolved: 20358 rows, 19956 columns, 70201 nonzeros
# Variable types: 17696 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.50 seconds (1.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.43197e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.431970322872e+07, best bound 2.431738862386e+07, gap 0.0095%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1078800 rows, 2035150 columns and 3793160 nonzeros
# Model fingerprint: 0x500f7ef1
# Variable types: 1956875 continuous, 78275 integer (78275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.43723e+07 (0.68s)
# Loaded MIP start from previous solve with objective 2.43723e+07
#
# Presolve removed 1058401 rows and 2015159 columns
# Presolve time: 0.43s
# Presolved: 20399 rows, 19991 columns, 70344 nonzeros
# Variable types: 17731 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.55 seconds (1.44 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.43723e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.437226237852e+07, best bound 2.436994770924e+07, gap 0.0095%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1113600 rows, 2100800 columns and 3915520 nonzeros
# Model fingerprint: 0x44ff5a64
# Variable types: 2020000 continuous, 80800 integer (80800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.44254e+07 (0.65s)
# Loaded MIP start from previous solve with objective 2.44254e+07
#
# Presolve removed 1093187 rows and 2080797 columns
# Presolve time: 0.41s
# Presolved: 20413 rows, 20003 columns, 70392 nonzeros
# Variable types: 17743 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.50 seconds (1.48 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.44254e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.442535798217e+07, best bound 2.442314414473e+07, gap 0.0091%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1148400 rows, 2166450 columns and 4037880 nonzeros
# Model fingerprint: 0xf7365fad
# Variable types: 2083125 continuous, 83325 integer (83325 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.44804e+07 (0.67s)
# Loaded MIP start from previous solve with objective 2.44804e+07
#
# Presolve removed 1127969 rows and 2146432 columns
# Presolve time: 0.42s
# Presolved: 20431 rows, 20018 columns, 70455 nonzeros
# Variable types: 17758 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      2.4480e+07 2.4478e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.57 seconds (1.53 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.44804e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.448039654125e+07, best bound 2.447802738622e+07, gap 0.0097%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1183200 rows, 2232100 columns and 4160240 nonzeros
# Model fingerprint: 0xfa45f6d6
# Variable types: 2146250 continuous, 85850 integer (85850 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 2.45282e+07 (0.71s)
# Loaded MIP start from previous solve with objective 2.45282e+07
#
# Presolve removed 1162745 rows and 2212059 columns
# Presolve time: 0.44s
# Presolved: 20455 rows, 20041 columns, 70545 nonzeros
# Variable types: 17781 continuous, 2260 integer (2260 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.61 seconds (1.57 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 2.45282e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.452824303268e+07, best bound 2.452586072715e+07, gap 0.0097%

# %%
sheet_name = sheet_list[6]
print(sheet_name)
data = read_data(xls, sheet_name=sheet_name)

start = time.time()
Z = Lagrangian_Relaxation_PLRF(data, optimal_values[sheet_name])
end = time.time()

results_LR.append((Z, end-start))
# Out:
# Data-200-24
# Iteration: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 69600 rows, 130650 columns and 244720 nonzeros
# Model fingerprint: 0x6d726050
# Variable types: 125625 continuous, 5025 integer (5025 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.384981e+08
# Presolve removed 56072 rows and 115366 columns
# Presolve time: 0.08s
# Presolved: 13528 rows, 15284 columns, 35842 nonzeros
# Found heuristic solution: objective 5.668860e+07
# Variable types: 10928 continuous, 4356 integer (4266 binary)
# Found heuristic solution: objective 3.889738e+07
#
# Root relaxation: objective 3.877388e+07, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3.877388e+07 3.8774e+07  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.22 seconds (0.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 3.87739e+07 3.88974e+07 5.66886e+07 1.38498e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.877387600000e+07, best bound 3.877387600000e+07, gap 0.0000%
# Iteration: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 139200 rows, 261300 columns and 489440 nonzeros
# Model fingerprint: 0xac9f9493
# Variable types: 251250 continuous, 10050 integer (10050 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.93246e+07 (0.23s)
# Loaded MIP start from previous solve with objective 3.93246e+07
#
# Presolve removed 100826 rows and 223384 columns
# Presolve time: 0.07s
# Presolved: 38374 rows, 37916 columns, 132332 nonzeros
# Variable types: 33396 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.53 seconds (0.54 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.93246e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.932456473406e+07, best bound 3.932101143955e+07, gap 0.0090%
# Iteration: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208800 rows, 391950 columns and 734160 nonzeros
# Model fingerprint: 0x92a19ebe
# Variable types: 376875 continuous, 15075 integer (15075 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 3.9854e+07 (0.32s)
# Loaded MIP start from previous solve with objective 3.9854e+07
#
# Presolve removed 170340 rows and 353966 columns
# Presolve time: 0.09s
# Presolved: 38460 rows, 37984 columns, 132606 nonzeros
# Variable types: 33464 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.68 seconds (0.68 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 3.9854e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.985401278683e+07, best bound 3.985046035701e+07, gap 0.0089%
# Iteration: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 278400 rows, 522600 columns and 978880 nonzeros
# Model fingerprint: 0x6bca9501
# Variable types: 502500 continuous, 20100 integer (20100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.03362e+07 (0.36s)
# Loaded MIP start from previous solve with objective 4.03362e+07
#
# Presolve removed 239734 rows and 484462 columns
# Presolve time: 0.13s
# Presolved: 38666 rows, 38138 columns, 133224 nonzeros
# Variable types: 33618 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.76 seconds (0.76 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.03362e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.033622032498e+07, best bound 4.033266874645e+07, gap 0.0088%
# Iteration: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 348000 rows, 653250 columns and 1223600 nonzeros
# Model fingerprint: 0x70512575
# Variable types: 628125 continuous, 25125 integer (25125 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.08053e+07 (0.38s)
# Loaded MIP start from previous solve with objective 4.08053e+07
#
# Presolve removed 309286 rows and 615072 columns
# Presolve time: 0.14s
# Presolved: 38714 rows, 38178 columns, 133390 nonzeros
# Variable types: 33658 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.81 seconds (0.84 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.08053e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.080527537667e+07, best bound 4.080172480503e+07, gap 0.0087%
# Iteration: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 417600 rows, 783900 columns and 1468320 nonzeros
# Model fingerprint: 0x2f228233
# Variable types: 753750 continuous, 30150 integer (30150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.12214e+07 (0.43s)
# Loaded MIP start from previous solve with objective 4.12214e+07
#
# Presolve removed 378736 rows and 745588 columns
# Presolve time: 0.17s
# Presolved: 38864 rows, 38312 columns, 133914 nonzeros
# Variable types: 33792 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.1221e+07 4.1218e+07  0.01%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.95 seconds (0.92 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.12214e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.122142116374e+07, best bound 4.121775289133e+07, gap 0.0089%
# Iteration: 7
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 487200 rows, 914550 columns and 1713040 nonzeros
# Model fingerprint: 0xfa2cd481
# Variable types: 879375 continuous, 35175 integer (35175 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.16407e+07 (0.47s)
# Loaded MIP start from previous solve with objective 4.16407e+07
#
# Presolve removed 448250 rows and 876166 columns
# Presolve time: 0.19s
# Presolved: 38950 rows, 38384 columns, 134198 nonzeros
# Variable types: 33864 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.1641e+07 4.1637e+07  0.01%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.98 seconds (1.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.16407e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.164067069233e+07, best bound 4.163660247826e+07, gap 0.0098%
# Iteration: 8
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 556800 rows, 1045200 columns and 1957760 nonzeros
# Model fingerprint: 0x1a730731
# Variable types: 1005000 continuous, 40200 integer (40200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+01, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.20533e+07 (0.49s)
# Loaded MIP start from previous solve with objective 4.20533e+07
#
# Presolve removed 517714 rows and 1006702 columns
# Presolve time: 0.21s
# Presolved: 39086 rows, 38498 columns, 134658 nonzeros
# Variable types: 33978 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.2053e+07 4.2049e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.06 seconds (1.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.20533e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.205332566726e+07, best bound 4.204929305083e+07, gap 0.0096%
# Iteration: 9
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 626400 rows, 1175850 columns and 2202480 nonzeros
# Model fingerprint: 0x75d7558f
# Variable types: 1130625 continuous, 45225 integer (45225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.2463e+07 (0.59s)
# Loaded MIP start from previous solve with objective 4.2463e+07
#
# Presolve removed 587246 rows and 1137296 columns
# Presolve time: 0.27s
# Presolved: 39154 rows, 38554 columns, 134882 nonzeros
# Variable types: 34034 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.2463e+07 4.2459e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.27 seconds (1.17 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.2463e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.246301741867e+07, best bound 4.245884774341e+07, gap 0.0098%
# Iteration: 10
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 696000 rows, 1306500 columns and 2447200 nonzeros
# Model fingerprint: 0x5a087de6
# Variable types: 1256250 continuous, 50250 integer (50250 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.28658e+07 (0.58s)
# Loaded MIP start from previous solve with objective 4.28658e+07
#
# Presolve removed 656710 rows and 1267830 columns
# Presolve time: 0.28s
# Presolved: 39290 rows, 38670 columns, 135350 nonzeros
# Variable types: 34150 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.2866e+07 4.2862e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.24 seconds (1.26 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.28658e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.286580640326e+07, best bound 4.286157187814e+07, gap 0.0099%
# Iteration: 11
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 765600 rows, 1437150 columns and 2691920 nonzeros
# Model fingerprint: 0x90911429
# Variable types: 1381875 continuous, 55275 integer (55275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [9e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.32689e+07 (0.59s)
# Loaded MIP start from previous solve with objective 4.32689e+07
#
# Presolve removed 726198 rows and 1398380 columns
# Presolve time: 0.29s
# Presolved: 39402 rows, 38770 columns, 135742 nonzeros
# Variable types: 34250 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.3269e+07 4.3265e+07  0.01%     -    1s
#
# Explored 1 nodes (3 simplex iterations) in 1.28 seconds (1.34 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.32689e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.326894005270e+07, best bound 4.326534456916e+07, gap 0.0083%
# Iteration: 12
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 835200 rows, 1567800 columns and 2936640 nonzeros
# Model fingerprint: 0xb6c60597
# Variable types: 1507500 continuous, 60300 integer (60300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.36477e+07 (0.66s)
# Loaded MIP start from previous solve with objective 4.36477e+07
#
# Presolve removed 795664 rows and 1528924 columns
# Presolve time: 0.35s
# Presolved: 39536 rows, 38876 columns, 136174 nonzeros
# Variable types: 34356 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.3648e+07 4.3643e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.46 seconds (1.43 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.36477e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.364765338282e+07, best bound 4.364338151740e+07, gap 0.0098%
# Iteration: 13
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 904800 rows, 1698450 columns and 3181360 nonzeros
# Model fingerprint: 0xbbaf532a
# Variable types: 1633125 continuous, 65325 integer (65325 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.4067e+07 (0.67s)
# Loaded MIP start from previous solve with objective 4.4067e+07
#
# Presolve removed 865120 rows and 1659456 columns
# Presolve time: 0.35s
# Presolved: 39680 rows, 38994 columns, 136666 nonzeros
# Variable types: 34474 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.4067e+07 4.4063e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.49 seconds (1.51 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.4067e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.406695516978e+07, best bound 4.406273385672e+07, gap 0.0096%
# Iteration: 14
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 974400 rows, 1829100 columns and 3426080 nonzeros
# Model fingerprint: 0xe2a21ad7
# Variable types: 1758750 continuous, 70350 integer (70350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [8e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.44714e+07 (0.74s)
# Loaded MIP start from previous solve with objective 4.44714e+07
#
# Presolve removed 934678 rows and 1790066 columns
# Presolve time: 0.40s
# Presolved: 39722 rows, 39034 columns, 136822 nonzeros
# Variable types: 34514 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.4471e+07 4.4467e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.63 seconds (1.59 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.44714e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.447138251438e+07, best bound 4.446713631697e+07, gap 0.0095%
# Iteration: 15
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1044000 rows, 1959750 columns and 3670800 nonzeros
# Model fingerprint: 0x1f10863f
# Variable types: 1884375 continuous, 75375 integer (75375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.4878e+07 (0.79s)
# Loaded MIP start from previous solve with objective 4.4878e+07
#
# Presolve removed 1004232 rows and 1920676 columns
# Presolve time: 0.41s
# Presolved: 39768 rows, 39074 columns, 136984 nonzeros
# Variable types: 34554 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.4878e+07 4.4874e+07  0.01%     -    1s
#
# Explored 1 nodes (2 simplex iterations) in 1.75 seconds (1.68 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.4878e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.487800289734e+07, best bound 4.487438886233e+07, gap 0.0081%
# Iteration: 16
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1113600 rows, 2090400 columns and 3915520 nonzeros
# Model fingerprint: 0x1f6b7647
# Variable types: 2010000 continuous, 80400 integer (80400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.52838e+07 (0.85s)
# Loaded MIP start from previous solve with objective 4.52838e+07
#
# Presolve removed 1073760 rows and 2051264 columns
# Presolve time: 0.43s
# Presolved: 39840 rows, 39136 columns, 137240 nonzeros
# Variable types: 34616 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.82 seconds (1.77 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.52838e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.528381486150e+07, best bound 4.527994952995e+07, gap 0.0085%
# Iteration: 17
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1183200 rows, 2221050 columns and 4160240 nonzeros
# Model fingerprint: 0x6793f80f
# Variable types: 2135625 continuous, 85425 integer (85425 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [7e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.56866e+07 (0.83s)
# Loaded MIP start from previous solve with objective 4.56866e+07
#
# Presolve removed 1143310 rows and 2181870 columns
# Presolve time: 0.47s
# Presolved: 39890 rows, 39180 columns, 137422 nonzeros
# Variable types: 34660 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 1.84 seconds (1.85 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.56866e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.568658937165e+07, best bound 4.568272394129e+07, gap 0.0085%
# Iteration: 18
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 1252800 rows, 2351700 columns and 4404960 nonzeros
# Model fingerprint: 0x542667ba
# Variable types: 2261250 continuous, 90450 integer (90450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.60826e+07 (0.95s)
# Loaded MIP start from previous solve with objective 4.60826e+07
# Processed MIP start in 1.06 seconds (0.90 work units)
#
# Presolve removed 1212826 rows and 2312436 columns
# Presolve time: 0.47s
# Presolved: 39974 rows, 39264 columns, 137758 nonzeros
# Variable types: 34744 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.6083e+07 4.6079e+07  0.01%     -    1s
#
# Explored 1 nodes (3 simplex iterations) in 2.00 seconds (1.94 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.60826e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.608261785356e+07, best bound 4.607919830993e+07, gap 0.0074%
# Iteration: 19
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1322400 rows, 2482350 columns and 4649680 nonzeros
# Model fingerprint: 0xb1932d70
# Variable types: 2386875 continuous, 95475 integer (95475 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.64318e+07 (0.96s)
# Loaded MIP start from previous solve with objective 4.64318e+07
# Processed MIP start in 1.07 seconds (0.94 work units)
#
# Presolve removed 1282352 rows and 2443030 columns
# Presolve time: 0.50s
# Presolved: 40048 rows, 39320 columns, 137992 nonzeros
# Variable types: 34800 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.6432e+07 4.6428e+07  0.01%     -    1s
#
# Explored 1 nodes (3 simplex iterations) in 2.08 seconds (2.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.64318e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.643184714749e+07, best bound 4.642821908404e+07, gap 0.0078%
# Iteration: 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1392000 rows, 2613000 columns and 4894400 nonzeros
# Model fingerprint: 0x01e03199
# Variable types: 2512500 continuous, 100500 integer (100500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.67158e+07 (0.91s)
# Loaded MIP start from previous solve with objective 4.67158e+07
# Processed MIP start in 1.01 seconds (0.98 work units)
#
# Presolve removed 1351862 rows and 2573594 columns
# Presolve time: 0.53s
# Presolved: 40138 rows, 39406 columns, 138338 nonzeros
# Variable types: 34886 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.03 seconds (2.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.67158e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.671583688219e+07, best bound 4.671173439177e+07, gap 0.0088%
# Iteration: 21
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1461600 rows, 2743650 columns and 5139120 nonzeros
# Model fingerprint: 0x5bc336fc
# Variable types: 2638125 continuous, 105525 integer (105525 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [6e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.69943e+07 (1.00s)
# Loaded MIP start from previous solve with objective 4.69943e+07
# Processed MIP start in 1.12 seconds (1.02 work units)
#
# Presolve removed 1421364 rows and 2704154 columns
# Presolve time: 0.55s
# Presolved: 40236 rows, 39496 columns, 138702 nonzeros
# Variable types: 34976 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.19 seconds (2.20 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.69943e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.699428400091e+07, best bound 4.698965432941e+07, gap 0.0099%
# Iteration: 22
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1531200 rows, 2874300 columns and 5383840 nonzeros
# Model fingerprint: 0x8a1592a0
# Variable types: 2763750 continuous, 110550 integer (110550 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.7257e+07 (1.03s)
# Loaded MIP start from previous solve with objective 4.7257e+07
# Processed MIP start in 1.13 seconds (1.06 work units)
#
# Presolve removed 1490850 rows and 2834704 columns
# Presolve time: 0.55s
# Presolved: 40350 rows, 39596 columns, 139100 nonzeros
# Variable types: 35076 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.22 seconds (2.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.7257e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.725704817412e+07, best bound 4.725241878853e+07, gap 0.0098%
# Iteration: 23
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1600800 rows, 3004950 columns and 5628560 nonzeros
# Model fingerprint: 0x6c7067a7
# Variable types: 2889375 continuous, 115575 integer (115575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.75179e+07 (1.12s)
# Loaded MIP start from previous solve with objective 4.75179e+07
# Processed MIP start in 1.26 seconds (1.09 work units)
#
# Presolve removed 1560398 rows and 2965308 columns
# Presolve time: 0.58s
# Presolved: 40402 rows, 39642 columns, 139288 nonzeros
# Variable types: 35122 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.40 seconds (2.37 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.75179e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.751793910337e+07, best bound 4.751330979482e+07, gap 0.0097%
# Iteration: 24
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1670400 rows, 3135600 columns and 5873280 nonzeros
# Model fingerprint: 0xe6bdd7f0
# Variable types: 3015000 continuous, 120600 integer (120600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 7e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.7725e+07 (1.14s)
# Loaded MIP start from previous solve with objective 4.7725e+07
# Processed MIP start in 1.26 seconds (1.13 work units)
#
# Presolve removed 1629940 rows and 3095910 columns
# Presolve time: 0.61s
# Presolved: 40460 rows, 39690 columns, 139490 nonzeros
# Variable types: 35170 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.44 seconds (2.45 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.7725e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.772495621460e+07, best bound 4.772032719093e+07, gap 0.0097%
# Iteration: 25
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1740000 rows, 3266250 columns and 6118000 nonzeros
# Model fingerprint: 0x343790a4
# Variable types: 3140625 continuous, 125625 integer (125625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.7933e+07 (1.09s)
# Loaded MIP start from previous solve with objective 4.7933e+07
# Processed MIP start in 1.23 seconds (1.17 work units)
#
# Presolve removed 1699510 rows and 3226530 columns
# Presolve time: 0.70s
# Presolved: 40490 rows, 39720 columns, 139610 nonzeros
# Variable types: 35200 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.53 seconds (2.54 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.7933e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.793301612220e+07, best bound 4.792838709368e+07, gap 0.0097%
# Iteration: 26
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1809600 rows, 3396900 columns and 6362720 nonzeros
# Model fingerprint: 0xecb6dae8
# Variable types: 3266250 continuous, 130650 integer (130650 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.80915e+07 (1.20s)
# Loaded MIP start from previous solve with objective 4.80915e+07
# Processed MIP start in 1.35 seconds (1.21 work units)
#
# Presolve removed 1769074 rows and 3357146 columns
# Presolve time: 0.65s
# Presolved: 40526 rows, 39754 columns, 139748 nonzeros
# Variable types: 35234 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.58 seconds (2.63 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.80915e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.809146397237e+07, best bound 4.808683481416e+07, gap 0.0096%
# Iteration: 27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1879200 rows, 3527550 columns and 6607440 nonzeros
# Model fingerprint: 0x14a94356
# Variable types: 3391875 continuous, 135675 integer (135675 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.82635e+07 (1.22s)
# Loaded MIP start from previous solve with objective 4.82635e+07
# Processed MIP start in 1.37 seconds (1.25 work units)
#
# Presolve removed 1838626 rows and 3487750 columns
# Presolve time: 0.70s
# Presolved: 40574 rows, 39800 columns, 139926 nonzeros
# Variable types: 35280 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.66 seconds (2.72 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.82635e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.826353601859e+07, best bound 4.825890698276e+07, gap 0.0096%
# Iteration: 28
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1948800 rows, 3658200 columns and 6852160 nonzeros
# Model fingerprint: 0xb207e990
# Variable types: 3517500 continuous, 140700 integer (140700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.83979e+07 (1.19s)
# Loaded MIP start from previous solve with objective 4.83979e+07
# Processed MIP start in 1.34 seconds (1.29 work units)
#
# Presolve removed 1908162 rows and 3618348 columns
# Presolve time: 0.70s
# Presolved: 40638 rows, 39852 columns, 140146 nonzeros
# Variable types: 35332 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.65 seconds (2.81 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.83979e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.839787296618e+07, best bound 4.839324381260e+07, gap 0.0096%
# Iteration: 29
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2018400 rows, 3788850 columns and 7096880 nonzeros
# Model fingerprint: 0x5f62c04b
# Variable types: 3643125 continuous, 145725 integer (145725 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.85187e+07 (1.30s)
# Loaded MIP start from previous solve with objective 4.85187e+07
# Processed MIP start in 1.46 seconds (1.33 work units)
#
# Presolve removed 1977736 rows and 3748978 columns
# Presolve time: 0.73s
# Presolved: 40664 rows, 39872 columns, 140232 nonzeros
# Variable types: 35352 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.83 seconds (2.90 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.85187e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.851871593540e+07, best bound 4.851408689074e+07, gap 0.0095%
# Iteration: 30
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2088000 rows, 3919500 columns and 7341600 nonzeros
# Model fingerprint: 0xfeaa4f70
# Variable types: 3768750 continuous, 150750 integer (150750 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.86394e+07 (1.32s)
# Loaded MIP start from previous solve with objective 4.86394e+07
# Processed MIP start in 1.49 seconds (1.36 work units)
#
# Presolve removed 2047284 rows and 3879588 columns
# Presolve time: 0.76s
# Presolved: 40716 rows, 39912 columns, 140402 nonzeros
# Variable types: 35392 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.87 seconds (2.98 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.86394e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.863940645743e+07, best bound 4.863477724772e+07, gap 0.0095%
# Iteration: 31
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2157600 rows, 4050150 columns and 7586320 nonzeros
# Model fingerprint: 0x0a2296c9
# Variable types: 3894375 continuous, 155775 integer (155775 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.87445e+07 (1.31s)
# Loaded MIP start from previous solve with objective 4.87445e+07
# Processed MIP start in 1.46 seconds (1.40 work units)
#
# Presolve removed 2116802 rows and 4010168 columns
# Presolve time: 0.77s
# Presolved: 40798 rows, 39982 columns, 140688 nonzeros
# Variable types: 35462 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 2.92 seconds (3.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.87445e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.874452475704e+07, best bound 4.873989541847e+07, gap 0.0095%
# Iteration: 32
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2227200 rows, 4180800 columns and 7831040 nonzeros
# Model fingerprint: 0xade4d00b
# Variable types: 4020000 continuous, 160800 integer (160800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.88507e+07 (1.43s)
# Loaded MIP start from previous solve with objective 4.88507e+07
# Processed MIP start in 1.61 seconds (1.44 work units)
#
# Presolve removed 2186374 rows and 4140794 columns
# Presolve time: 0.80s
# Presolved: 40826 rows, 40006 columns, 140784 nonzeros
# Variable types: 35486 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 3.13 seconds (3.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.88507e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.885071596435e+07, best bound 4.884628828946e+07, gap 0.0091%
# Iteration: 33
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2296800 rows, 4311450 columns and 8075760 nonzeros
# Model fingerprint: 0xa21cae64
# Variable types: 4145625 continuous, 165825 integer (165825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.89608e+07 (1.46s)
# Loaded MIP start from previous solve with objective 4.89608e+07
# Processed MIP start in 1.65 seconds (1.48 work units)
#
# Presolve removed 2255938 rows and 4271414 columns
# Presolve time: 0.85s
# Presolved: 40862 rows, 40036 columns, 140910 nonzeros
# Variable types: 35516 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      4.8961e+07 4.8957e+07  0.01%     -    3s
#
# Explored 1 nodes (2 simplex iterations) in 3.18 seconds (3.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.89608e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.896079308250e+07, best bound 4.895682601375e+07, gap 0.0081%
# Iteration: 34
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 2366400 rows, 4442100 columns and 8320480 nonzeros
# Model fingerprint: 0x2c43d92b
# Variable types: 4271250 continuous, 170850 integer (170850 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [5e+00, 8e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 4.90565e+07 (1.43s)
# Loaded MIP start from previous solve with objective 4.90565e+07
# Processed MIP start in 1.60 seconds (1.52 work units)
#
# Presolve removed 2325490 rows and 4402018 columns
# Presolve time: 0.84s
# Presolved: 40910 rows, 40082 columns, 141090 nonzeros
# Variable types: 35562 continuous, 4520 integer (4520 binary)
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 3.14 seconds (3.33 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 4.90565e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.905648606536e+07, best bound 4.905172145429e+07, gap 0.0097%

# %%
print(results_LR)
# Out:
# [(85839.08850058631, 10.781669616699219), (11178354.328293849, 7.170841693878174), (5125614.4162301775, 21.626482486724854), (5211460.110143085, 22.371801614761353), (24528243.032682203, 102.2843930721283), (24528243.032682203, 103.09551882743835), (49056486.065364346, 207.29092359542847)]
